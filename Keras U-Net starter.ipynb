# %% [markdown]
# # Intro
# Hello! This rather quick and dirty kernel shows how to get started on segmenting nuclei using a neural network in Keras.
#
# The architecture used is the so-called [U-Net](https://arxiv.org/abs/1505.04597), which is very common for image segmentation problems such as this. I believe they also have a tendency to work quite well even on small datasets.
#
# Let's get started importing everything we need!

# %%
import os
import sys
import random
import warnings

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

from tqdm import tqdm
from itertools import chain
from skimage.io import imread, imshow, imread_collection, concatenate_images
from skimage.transform import resize
from skimage.morphology import label

from keras.models import Model, load_model
from keras.layers import Input
from keras.layers.core import Dropout, Lambda
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D
from keras.layers.merge import concatenate
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras import backend as K

import tensorflow as tf

# Set some parameters
IMG_WIDTH = 128
IMG_HEIGHT = 128
IMG_CHANNELS = 3
TRAIN_PATH = 'data/stage1_train/'
TEST_PATH = 'data/stage1_test/'

warnings.filterwarnings('ignore', category=UserWarning, module='skimage')
seed = 42
random.seed = seed
np.random.seed = seed

# %%
# Get train and test IDs
train_ids = next(os.walk(TRAIN_PATH))[1]
test_ids = next(os.walk(TEST_PATH))[1]

# %% [markdown]
# # Get the data
# Let's first import all the images and associated masks. I downsample both the training and test images to keep things light and manageable, but we need to keep a record of the original sizes of the test images to upsample our predicted masks and create correct run-length encodings later on. There are definitely better ways to handle this, but it works fine for now!

# %%
# Get and resize train images and masks
X_train = np.zeros((len(train_ids), IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.uint8)
Y_train = np.zeros((len(train_ids), IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.bool)
print('Getting and resizing train images and masks ... ')
sys.stdout.flush()
for n, id_ in tqdm(enumerate(train_ids), total=len(train_ids)):
    path = TRAIN_PATH + id_
    img = imread(path + '/images/' + id_ + '.png')[:,:,:IMG_CHANNELS]
    img = resize(img, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)
    X_train[n] = img
    mask = np.zeros((IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.bool)
    for mask_file in next(os.walk(path + '/masks/'))[2]:
        mask_ = imread(path + '/masks/' + mask_file)
        mask_ = np.expand_dims(resize(mask_, (IMG_HEIGHT, IMG_WIDTH), mode='constant', 
                                      preserve_range=True), axis=-1)
        mask = np.maximum(mask, mask_)
    Y_train[n] = mask

# Get and resize test images
X_test = np.zeros((len(test_ids), IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.uint8)
sizes_test = []
print('Getting and resizing test images ... ')
sys.stdout.flush()
for n, id_ in tqdm(enumerate(test_ids), total=len(test_ids)):
    path = TEST_PATH + id_
    img = imread(path + '/images/' + id_ + '.png')[:,:,:IMG_CHANNELS]
    sizes_test.append([img.shape[0], img.shape[1]])
    img = resize(img, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)
    X_test[n] = img

print('Done!')
# Out:
# Getting and resizing train images and masks ...
# 100%|████████████████████████████████████████████████████████████████████████████████| 670/670 [01:26<00:00,  7.76it/s]
# Getting and resizing test images ...
# 100%|██████████████████████████████████████████████████████████████████████████████████| 65/65 [00:00<00:00, 91.29it/s]
# Done!

# %% [markdown]
# Let's see if things look all right by drawing some random images and their associated masks.

# %%
# Check if training data looks all right
ix = random.randint(0, len(train_ids))
imshow(X_train[ix])
plt.show()
imshow(np.squeeze(Y_train[ix]))
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and

# %% [markdown]
# Seems good!
#
# # Create our Keras metric
#
# Now we try to define the *mean average precision at different intersection over union (IoU) thresholds* metric in Keras. TensorFlow has a mean IoU metric, but it doesn't have any native support for the mean over multiple thresholds, so I tried to implement this. **I'm by no means certain that this implementation is correct, though!** Any assistance in verifying this would be most welcome!
#
# *Update: This implementation is most definitely not correct due to the very large discrepancy between the results reported here and the LB results. It also seems to just increase over time no matter what when you train ... *

# %%
# Define IoU metric
def mean_iou(y_true, y_pred):
    prec = []
    for t in np.arange(0.5, 1.0, 0.05):
        y_pred_ = tf.to_int32(y_pred > t)
        score, up_opt = tf.metrics.mean_iou(y_true, y_pred_, 2)
        K.get_session().run(tf.local_variables_initializer())
        with tf.control_dependencies([up_opt]):
            score = tf.identity(score)
        prec.append(score)
    return K.mean(K.stack(prec), axis=0)

# %% [markdown]
# # Build and train our neural network
# Next we build our U-Net model, loosely based on [U-Net: Convolutional Networks for Biomedical Image Segmentation](https://arxiv.org/pdf/1505.04597.pdf) and very similar to [this repo](https://github.com/jocicmarko/ultrasound-nerve-segmentation) from the Kaggle Ultrasound Nerve Segmentation competition.
#
# ![](https://lmb.informatik.uni-freiburg.de/people/ronneber/u-net/u-net-architecture.png)

# %%
# Build U-Net model
inputs = Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))
s = Lambda(lambda x: x / 255) (inputs)

c1 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (s)
c1 = Dropout(0.1) (c1)
c1 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c1)
p1 = MaxPooling2D((2, 2)) (c1)

c2 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p1)
c2 = Dropout(0.1) (c2)
c2 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c2)
p2 = MaxPooling2D((2, 2)) (c2)

c3 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p2)
c3 = Dropout(0.2) (c3)
c3 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c3)
p3 = MaxPooling2D((2, 2)) (c3)

c4 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p3)
c4 = Dropout(0.2) (c4)
c4 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c4)
p4 = MaxPooling2D(pool_size=(2, 2)) (c4)

c5 = Conv2D(256, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p4)
c5 = Dropout(0.3) (c5)
c5 = Conv2D(256, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c5)

u6 = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same') (c5)
u6 = concatenate([u6, c4])
c6 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u6)
c6 = Dropout(0.2) (c6)
c6 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c6)

u7 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same') (c6)
u7 = concatenate([u7, c3])
c7 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u7)
c7 = Dropout(0.2) (c7)
c7 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c7)

u8 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same') (c7)
u8 = concatenate([u8, c2])
c8 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u8)
c8 = Dropout(0.1) (c8)
c8 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c8)

u9 = Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same') (c8)
u9 = concatenate([u9, c1], axis=3)
c9 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u9)
c9 = Dropout(0.1) (c9)
c9 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c9)

outputs = Conv2D(1, (1, 1), activation='sigmoid') (c9)

model = Model(inputs=[inputs], outputs=[outputs])
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=[mean_iou])
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 128, 128, 3)  0
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 128, 128, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 128, 128, 16) 448         lambda_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 128, 128, 16) 0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 128, 128, 16) 2320        dropout_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 16)   0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 64, 64, 32)   4640        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 64, 64, 32)   0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 64, 64, 32)   9248        dropout_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 32)   0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 64)   18496       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 32, 32, 64)   0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 64)   36928       dropout_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 64)   0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 16, 16, 128)  73856       max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 16, 16, 128)  0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 16, 128)  147584      dropout_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 8, 8, 128)    0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 8, 8, 256)    295168      max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 8, 8, 256)    0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 8, 8, 256)    590080      dropout_5[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 16, 16, 128)  131200      conv2d_10[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 16, 16, 256)  0           conv2d_transpose_1[0][0]
#                                                                  conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 16, 16, 128)  295040      concatenate_1[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 16, 16, 128)  0           conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 16, 16, 128)  147584      dropout_6[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 32, 32, 64)   32832       conv2d_12[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 32, 32, 128)  0           conv2d_transpose_2[0][0]
#                                                                  conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 32, 32, 64)   73792       concatenate_2[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 32, 32, 64)   0           conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 32, 32, 64)   36928       dropout_7[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 64, 64, 32)   8224        conv2d_14[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 64, 64, 64)   0           conv2d_transpose_3[0][0]
#                                                                  conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 64, 64, 32)   18464       concatenate_3[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 64, 64, 32)   0           conv2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 64, 64, 32)   9248        dropout_8[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 128, 128, 16) 2064        conv2d_16[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 128, 128, 32) 0           conv2d_transpose_4[0][0]
#                                                                  conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 128, 128, 16) 4624        concatenate_4[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 128, 128, 16) 0           conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 128, 128, 16) 2320        dropout_9[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 128, 128, 1)  17          conv2d_18[0][0]
# ==================================================================================================
# Total params: 1,941,105
# Trainable params: 1,941,105
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# *Update: Changed to ELU units, added dropout.*
#
# Next we fit the model on the training data, using a validation split of 0.1. We use a small batch size because we have so little data. I recommend using checkpointing and early stopping when training your model. I won't do it here to make things a bit more reproducible (although it's very likely that your results will be different anyway). I'll just train for 10 epochs, which takes around 10 minutes in the Kaggle kernel with the current parameters.
#
# *Update: Added early stopping and checkpointing and increased to 30 epochs.*

# %%
# Fit model
earlystopper = EarlyStopping(patience=5, verbose=1)
checkpointer = ModelCheckpoint('model-dsbowl2018-1.h5', verbose=1, save_best_only=True)
results = model.fit(X_train, Y_train, validation_split=0.1, batch_size=16, epochs=50, 
                    callbacks=[earlystopper, checkpointer])
# Out:
# Train on 603 samples, validate on 67 samples
# Epoch 1/50
# 592/603 [============================>.] - ETA: 1:39 - loss: 0.7298 - mean_iou: 0.0000e+ - ETA: 1:18 - loss: 0.6929 - mean_iou: 0.2079   - ETA: 1:10 - loss: 0.6600 - mean_iou: 0.27 - ETA: 1:04 - loss: 0.6121 - mean_iou: 0.31 - ETA: 1:01 - loss: 0.5781 - mean_iou: 0.33 - ETA: 58s - loss: 0.5719 - mean_iou: 0.3548 - ETA: 55s - loss: 0.5557 - mean_iou: 0.365 - ETA: 52s - loss: 0.5447 - mean_iou: 0.373 - ETA: 50s - loss: 0.5445 - mean_iou: 0.379 - ETA: 48s - loss: 0.5378 - mean_iou: 0.383 - ETA: 46s - loss: 0.5306 - mean_iou: 0.387 - ETA: 44s - loss: 0.5170 - mean_iou: 0.389 - ETA: 42s - loss: 0.5529 - mean_iou: 0.392 - ETA: 40s - loss: 0.5425 - mean_iou: 0.394 - ETA: 38s - loss: 0.5341 - mean_iou: 0.396 - ETA: 37s - loss: 0.5260 - mean_iou: 0.398 - ETA: 35s - loss: 0.5228 - mean_iou: 0.400 - ETA: 33s - loss: 0.5207 - mean_iou: 0.401 - ETA: 31s - loss: 0.5131 - mean_iou: 0.402 - ETA: 29s - loss: 0.5085 - mean_iou: 0.403 - ETA: 28s - loss: 0.5062 - mean_iou: 0.404 - ETA: 26s - loss: 0.4994 - mean_iou: 0.405 - ETA: 24s - loss: 0.4933 - mean_iou: 0.406 - ETA: 23s - loss: 0.4906 - mean_iou: 0.407 - ETA: 21s - loss: 0.4884 - mean_iou: 0.407 - ETA: 19s - loss: 0.4845 - mean_iou: 0.408 - ETA: 17s - loss: 0.4813 - mean_iou: 0.409 - ETA: 16s - loss: 0.4825 - mean_iou: 0.409 - ETA: 14s - loss: 0.4834 - mean_iou: 0.410 - ETA: 12s - loss: 0.4812 - mean_iou: 0.410 - ETA: 11s - loss: 0.4791 - mean_iou: 0.411 - ETA: 9s - loss: 0.4768 - mean_iou: 0.411 - ETA: 7s - loss: 0.4752 - mean_iou: 0.41 - ETA: 6s - loss: 0.4751 - mean_iou: 0.41 - ETA: 4s - loss: 0.4723 - mean_iou: 0.41 - ETA: 2s - loss: 0.4728 - mean_iou: 0.41 - ETA: 1s - loss: 0.4703 - mean_iou: 0.4135
# Epoch 00001: val_loss improved from inf to 0.38558, saving model to model-dsbowl2018-1.h5
# 603/603 [==============================] - 66s 109ms/step - loss: 0.4691 - mean_iou: 0.4137 - val_loss: 0.3856 - val_mean_iou: 0.4254
# Epoch 2/50
# 592/603 [============================>.] - ETA: 1:00 - loss: 0.3622 - mean_iou: 0.42 - ETA: 59s - loss: 0.3777 - mean_iou: 0.4265 - ETA: 58s - loss: 0.3893 - mean_iou: 0.426 - ETA: 57s - loss: 0.3824 - mean_iou: 0.426 - ETA: 55s - loss: 0.3761 - mean_iou: 0.427 - ETA: 53s - loss: 0.3828 - mean_iou: 0.427 - ETA: 52s - loss: 0.3943 - mean_iou: 0.427 - ETA: 50s - loss: 0.3890 - mean_iou: 0.427 - ETA: 48s - loss: 0.3923 - mean_iou: 0.427 - ETA: 46s - loss: 0.3958 - mean_iou: 0.428 - ETA: 45s - loss: 0.3978 - mean_iou: 0.428 - ETA: 43s - loss: 0.4064 - mean_iou: 0.428 - ETA: 41s - loss: 0.4062 - mean_iou: 0.428 - ETA: 40s - loss: 0.4066 - mean_iou: 0.428 - ETA: 38s - loss: 0.4064 - mean_iou: 0.429 - ETA: 36s - loss: 0.4035 - mean_iou: 0.429 - ETA: 35s - loss: 0.4010 - mean_iou: 0.429 - ETA: 33s - loss: 0.3973 - mean_iou: 0.429 - ETA: 31s - loss: 0.3935 - mean_iou: 0.429 - ETA: 29s - loss: 0.3949 - mean_iou: 0.429 - ETA: 28s - loss: 0.3912 - mean_iou: 0.429 - ETA: 26s - loss: 0.3907 - mean_iou: 0.429 - ETA: 24s - loss: 0.3908 - mean_iou: 0.429 - ETA: 23s - loss: 0.3919 - mean_iou: 0.430 - ETA: 21s - loss: 0.3903 - mean_iou: 0.430 - ETA: 19s - loss: 0.3900 - mean_iou: 0.430 - ETA: 18s - loss: 0.3892 - mean_iou: 0.430 - ETA: 16s - loss: 0.3861 - mean_iou: 0.430 - ETA: 14s - loss: 0.3850 - mean_iou: 0.430 - ETA: 12s - loss: 0.3839 - mean_iou: 0.430 - ETA: 11s - loss: 0.3824 - mean_iou: 0.430 - ETA: 9s - loss: 0.3812 - mean_iou: 0.430 - ETA: 7s - loss: 0.3784 - mean_iou: 0.43 - ETA: 6s - loss: 0.3751 - mean_iou: 0.43 - ETA: 4s - loss: 0.3739 - mean_iou: 0.43 - ETA: 2s - loss: 0.3679 - mean_iou: 0.43 - ETA: 1s - loss: 0.3648 - mean_iou: 0.4318
# Epoch 00002: val_loss improved from 0.38558 to 0.25663, saving model to model-dsbowl2018-1.h5
# 603/603 [==============================] - 66s 109ms/step - loss: 0.3626 - mean_iou: 0.4320 - val_loss: 0.2566 - val_mean_iou: 0.4412
# Epoch 3/50
# 592/603 [============================>.] - ETA: 1:03 - loss: 0.1817 - mean_iou: 0.44 - ETA: 1:00 - loss: 0.2430 - mean_iou: 0.44 - ETA: 59s - loss: 0.2432 - mean_iou: 0.4433 - ETA: 58s - loss: 0.2635 - mean_iou: 0.444 - ETA: 57s - loss: 0.2579 - mean_iou: 0.444 - ETA: 55s - loss: 0.2546 - mean_iou: 0.445 - ETA: 53s - loss: 0.2467 - mean_iou: 0.446 - ETA: 51s - loss: 0.2376 - mean_iou: 0.446 - ETA: 49s - loss: 0.2382 - mean_iou: 0.447 - ETA: 47s - loss: 0.2401 - mean_iou: 0.448 - ETA: 46s - loss: 0.2349 - mean_iou: 0.449 - ETA: 44s - loss: 0.2428 - mean_iou: 0.449 - ETA: 42s - loss: 0.2415 - mean_iou: 0.450 - ETA: 41s - loss: 0.2394 - mean_iou: 0.451 - ETA: 39s - loss: 0.2387 - mean_iou: 0.452 - ETA: 37s - loss: 0.2359 - mean_iou: 0.453 - ETA: 35s - loss: 0.2350 - mean_iou: 0.454 - ETA: 33s - loss: 0.2317 - mean_iou: 0.455 - ETA: 31s - loss: 0.2309 - mean_iou: 0.456 - ETA: 30s - loss: 0.2325 - mean_iou: 0.457 - ETA: 28s - loss: 0.2296 - mean_iou: 0.457 - ETA: 26s - loss: 0.2288 - mean_iou: 0.458 - ETA: 24s - loss: 0.2282 - mean_iou: 0.459 - ETA: 23s - loss: 0.2273 - mean_iou: 0.460 - ETA: 21s - loss: 0.2254 - mean_iou: 0.461 - ETA: 19s - loss: 0.2220 - mean_iou: 0.462 - ETA: 18s - loss: 0.2230 - mean_iou: 0.463 - ETA: 16s - loss: 0.2224 - mean_iou: 0.463 - ETA: 14s - loss: 0.2189 - mean_iou: 0.464 - ETA: 13s - loss: 0.2204 - mean_iou: 0.465 - ETA: 11s - loss: 0.2180 - mean_iou: 0.466 - ETA: 9s - loss: 0.2171 - mean_iou: 0.467 - ETA: 7s - loss: 0.2156 - mean_iou: 0.46 - ETA: 6s - loss: 0.2154 - mean_iou: 0.46 - ETA: 4s - loss: 0.2141 - mean_iou: 0.46 - ETA: 2s - loss: 0.2120 - mean_iou: 0.47 - ETA: 1s - loss: 0.2102 - mean_iou: 0.4716
# Epoch 00003: val_loss improved from 0.25663 to 0.17236, saving model to model-dsbowl2018-1.h5
# 603/603 [==============================] - 67s 110ms/step - loss: 0.2083 - mean_iou: 0.4722 - val_loss: 0.1724 - val_mean_iou: 0.5085
# Epoch 4/50
# 592/603 [============================>.] - ETA: 1:00 - loss: 0.1581 - mean_iou: 0.51 - ETA: 58s - loss: 0.1606 - mean_iou: 0.5126 - ETA: 57s - loss: 0.1559 - mean_iou: 0.513 - ETA: 55s - loss: 0.1554 - mean_iou: 0.513 - ETA: 53s - loss: 0.1674 - mean_iou: 0.514 - ETA: 52s - loss: 0.1629 - mean_iou: 0.514 - ETA: 50s - loss: 0.1621 - mean_iou: 0.515 - ETA: 49s - loss: 0.1645 - mean_iou: 0.515 - ETA: 47s - loss: 0.1645 - mean_iou: 0.516 - ETA: 46s - loss: 0.1625 - mean_iou: 0.517 - ETA: 44s - loss: 0.1626 - mean_iou: 0.517 - ETA: 42s - loss: 0.1628 - mean_iou: 0.518 - ETA: 41s - loss: 0.1593 - mean_iou: 0.519 - ETA: 39s - loss: 0.1636 - mean_iou: 0.520 - ETA: 38s - loss: 0.1620 - mean_iou: 0.520 - ETA: 36s - loss: 0.1592 - mean_iou: 0.521 - ETA: 34s - loss: 0.1581 - mean_iou: 0.522 - ETA: 33s - loss: 0.1583 - mean_iou: 0.523 - ETA: 31s - loss: 0.1625 - mean_iou: 0.523 - ETA: 29s - loss: 0.1645 - mean_iou: 0.524 - ETA: 28s - loss: 0.1616 - mean_iou: 0.525 - ETA: 26s - loss: 0.1608 - mean_iou: 0.526 - ETA: 24s - loss: 0.1601 - mean_iou: 0.526 - ETA: 23s - loss: 0.1618 - mean_iou: 0.527 - ETA: 21s - loss: 0.1612 - mean_iou: 0.528 - ETA: 19s - loss: 0.1614 - mean_iou: 0.529 - ETA: 18s - loss: 0.1599 - mean_iou: 0.529 - ETA: 16s - loss: 0.1584 - mean_iou: 0.530 - ETA: 14s - loss: 0.1593 - mean_iou: 0.531 - ETA: 13s - loss: 0.1582 - mean_iou: 0.531 - ETA: 11s - loss: 0.1566 - mean_iou: 0.532 - ETA: 9s - loss: 0.1557 - mean_iou: 0.533 - ETA: 7s - loss: 0.1554 - mean_iou: 0.53 - ETA: 6s - loss: 0.1543 - mean_iou: 0.53 - ETA: 4s - loss: 0.1533 - mean_iou: 0.53 - ETA: 2s - loss: 0.1535 - mean_iou: 0.53 - ETA: 1s - loss: 0.1529 - mean_iou: 0.5367
# Epoch 00004: val_loss improved from 0.17236 to 0.13801, saving model to model-dsbowl2018-1.h5
# 603/603 [==============================] - 67s 111ms/step - loss: 0.1517 - mean_iou: 0.5372 - val_loss: 0.1380 - val_mean_iou: 0.5648
# Epoch 5/50
# 592/603 [============================>.] - ETA: 1:07 - loss: 0.1286 - mean_iou: 0.56 - ETA: 1:05 - loss: 0.1179 - mean_iou: 0.56 - ETA: 1:02 - loss: 0.1389 - mean_iou: 0.56 - ETA: 1:00 - loss: 0.1624 - mean_iou: 0.57 - ETA: 59s - loss: 0.1560 - mean_iou: 0.5708 - ETA: 57s - loss: 0.1526 - mean_iou: 0.571 - ETA: 55s - loss: 0.1457 - mean_iou: 0.572 - ETA: 53s - loss: 0.1455 - mean_iou: 0.572 - ETA: 51s - loss: 0.1436 - mean_iou: 0.573 - ETA: 50s - loss: 0.1549 - mean_iou: 0.573 - ETA: 48s - loss: 0.1522 - mean_iou: 0.574 - ETA: 46s - loss: 0.1516 - mean_iou: 0.574 - ETA: 44s - loss: 0.1551 - mean_iou: 0.574 - ETA: 42s - loss: 0.1525 - mean_iou: 0.575 - ETA: 40s - loss: 0.1487 - mean_iou: 0.575 - ETA: 38s - loss: 0.1477 - mean_iou: 0.576 - ETA: 36s - loss: 0.1508 - mean_iou: 0.576 - ETA: 34s - loss: 0.1504 - mean_iou: 0.577 - ETA: 33s - loss: 0.1483 - mean_iou: 0.577 - ETA: 31s - loss: 0.1478 - mean_iou: 0.578 - ETA: 29s - loss: 0.1470 - mean_iou: 0.578 - ETA: 27s - loss: 0.1460 - mean_iou: 0.579 - ETA: 25s - loss: 0.1435 - mean_iou: 0.579 - ETA: 23s - loss: 0.1448 - mean_iou: 0.580 - ETA: 22s - loss: 0.1434 - mean_iou: 0.580 - ETA: 20s - loss: 0.1426 - mean_iou: 0.581 - ETA: 18s - loss: 0.1418 - mean_iou: 0.581 - ETA: 16s - loss: 0.1431 - mean_iou: 0.582 - ETA: 15s - loss: 0.1431 - mean_iou: 0.582 - ETA: 13s - loss: 0.1444 - mean_iou: 0.582 - ETA: 11s - loss: 0.1431 - mean_iou: 0.583 - ETA: 9s - loss: 0.1444 - mean_iou: 0.583 - ETA: 8s - loss: 0.1435 - mean_iou: 0.58 - ETA: 6s - loss: 0.1432 - mean_iou: 0.58 - ETA: 4s - loss: 0.1422 - mean_iou: 0.58 - ETA: 2s - loss: 0.1429 - mean_iou: 0.58 - ETA: 1s - loss: 0.1430 - mean_iou: 0.5860
# Epoch 00005: val_loss did not improve
# 603/603 [==============================] - 67s 111ms/step - loss: 0.1420 - mean_iou: 0.5863 - val_loss: 0.1679 - val_mean_iou: 0.6047
# Epoch 6/50
# 592/603 [============================>.] - ETA: 1:01 - loss: 0.1262 - mean_iou: 0.60 - ETA: 1:00 - loss: 0.1432 - mean_iou: 0.60 - ETA: 58s - loss: 0.1346 - mean_iou: 0.6071 - ETA: 56s - loss: 0.1399 - mean_iou: 0.607 - ETA: 54s - loss: 0.1408 - mean_iou: 0.607 - ETA: 52s - loss: 0.1354 - mean_iou: 0.608 - ETA: 51s - loss: 0.1289 - mean_iou: 0.608 - ETA: 50s - loss: 0.1283 - mean_iou: 0.608 - ETA: 48s - loss: 0.1228 - mean_iou: 0.609 - ETA: 46s - loss: 0.1228 - mean_iou: 0.609 - ETA: 45s - loss: 0.1207 - mean_iou: 0.609 - ETA: 43s - loss: 0.1232 - mean_iou: 0.610 - ETA: 41s - loss: 0.1203 - mean_iou: 0.610 - ETA: 39s - loss: 0.1221 - mean_iou: 0.611 - ETA: 38s - loss: 0.1205 - mean_iou: 0.611 - ETA: 36s - loss: 0.1222 - mean_iou: 0.611 - ETA: 35s - loss: 0.1241 - mean_iou: 0.612 - ETA: 33s - loss: 0.1236 - mean_iou: 0.612 - ETA: 31s - loss: 0.1233 - mean_iou: 0.613 - ETA: 29s - loss: 0.1258 - mean_iou: 0.613 - ETA: 28s - loss: 0.1255 - mean_iou: 0.613 - ETA: 26s - loss: 0.1257 - mean_iou: 0.614 - ETA: 24s - loss: 0.1249 - mean_iou: 0.614 - ETA: 23s - loss: 0.1235 - mean_iou: 0.614 - ETA: 21s - loss: 0.1239 - mean_iou: 0.615 - ETA: 19s - loss: 0.1235 - mean_iou: 0.615 - ETA: 18s - loss: 0.1245 - mean_iou: 0.616 - ETA: 16s - loss: 0.1251 - mean_iou: 0.616 - ETA: 14s - loss: 0.1244 - mean_iou: 0.616 - ETA: 13s - loss: 0.1235 - mean_iou: 0.617 - ETA: 11s - loss: 0.1227 - mean_iou: 0.617 - ETA: 9s - loss: 0.1219 - mean_iou: 0.617 - ETA: 7s - loss: 0.1213 - mean_iou: 0.61 - ETA: 6s - loss: 0.1230 - mean_iou: 0.61 - ETA: 4s - loss: 0.1219 - mean_iou: 0.61 - ETA: 2s - loss: 0.1221 - mean_iou: 0.61 - ETA: 1s - loss: 0.1222 - mean_iou: 0.6198
# Epoch 00006: val_loss improved from 0.13801 to 0.11220, saving model to model-dsbowl2018-1.h5
# 603/603 [==============================] - 67s 111ms/step - loss: 0.1219 - mean_iou: 0.6200 - val_loss: 0.1122 - val_mean_iou: 0.6349
# Epoch 7/50
# 592/603 [============================>.] - ETA: 1:00 - loss: 0.1316 - mean_iou: 0.63 - ETA: 59s - loss: 0.1344 - mean_iou: 0.6369 - ETA: 57s - loss: 0.1272 - mean_iou: 0.637 - ETA: 56s - loss: 0.1196 - mean_iou: 0.637 - ETA: 54s - loss: 0.1208 - mean_iou: 0.637 - ETA: 52s - loss: 0.1214 - mean_iou: 0.638 - ETA: 51s - loss: 0.1259 - mean_iou: 0.638 - ETA: 49s - loss: 0.1255 - mean_iou: 0.638 - ETA: 47s - loss: 0.1247 - mean_iou: 0.639 - ETA: 46s - loss: 0.1219 - mean_iou: 0.639 - ETA: 44s - loss: 0.1189 - mean_iou: 0.639 - ETA: 42s - loss: 0.1197 - mean_iou: 0.639 - ETA: 41s - loss: 0.1203 - mean_iou: 0.640 - ETA: 39s - loss: 0.1176 - mean_iou: 0.640 - ETA: 37s - loss: 0.1165 - mean_iou: 0.640 - ETA: 36s - loss: 0.1174 - mean_iou: 0.641 - ETA: 34s - loss: 0.1169 - mean_iou: 0.641 - ETA: 32s - loss: 0.1160 - mean_iou: 0.641 - ETA: 31s - loss: 0.1161 - mean_iou: 0.641 - ETA: 29s - loss: 0.1170 - mean_iou: 0.642 - ETA: 27s - loss: 0.1153 - mean_iou: 0.642 - ETA: 26s - loss: 0.1140 - mean_iou: 0.642 - ETA: 24s - loss: 0.1129 - mean_iou: 0.643 - ETA: 22s - loss: 0.1133 - mean_iou: 0.643 - ETA: 21s - loss: 0.1124 - mean_iou: 0.643 - ETA: 19s - loss: 0.1114 - mean_iou: 0.644 - ETA: 17s - loss: 0.1110 - mean_iou: 0.644 - ETA: 16s - loss: 0.1120 - mean_iou: 0.644 - ETA: 14s - loss: 0.1127 - mean_iou: 0.644 - ETA: 12s - loss: 0.1113 - mean_iou: 0.645 - ETA: 11s - loss: 0.1102 - mean_iou: 0.645 - ETA: 9s - loss: 0.1104 - mean_iou: 0.645 - ETA: 7s - loss: 0.1113 - mean_iou: 0.64 - ETA: 6s - loss: 0.1108 - mean_iou: 0.64 - ETA: 4s - loss: 0.1114 - mean_iou: 0.64 - ETA: 2s - loss: 0.1118 - mean_iou: 0.64 - ETA: 1s - loss: 0.1118 - mean_iou: 0.6473
# Epoch 00007: val_loss improved from 0.11220 to 0.10619, saving model to model-dsbowl2018-1.h5
# 603/603 [==============================] - 67s 111ms/step - loss: 0.1112 - mean_iou: 0.6475 - val_loss: 0.1062 - val_mean_iou: 0.6594
# Epoch 8/50
# 592/603 [============================>.] - ETA: 1:08 - loss: 0.1103 - mean_iou: 0.66 - ETA: 1:04 - loss: 0.0998 - mean_iou: 0.66 - ETA: 1:01 - loss: 0.1069 - mean_iou: 0.66 - ETA: 58s - loss: 0.1203 - mean_iou: 0.6614 - ETA: 56s - loss: 0.1161 - mean_iou: 0.661 - ETA: 54s - loss: 0.1059 - mean_iou: 0.662 - ETA: 52s - loss: 0.1064 - mean_iou: 0.662 - ETA: 50s - loss: 0.1022 - mean_iou: 0.662 - ETA: 49s - loss: 0.1061 - mean_iou: 0.662 - ETA: 47s - loss: 0.1066 - mean_iou: 0.663 - ETA: 45s - loss: 0.1059 - mean_iou: 0.663 - ETA: 43s - loss: 0.1090 - mean_iou: 0.663 - ETA: 41s - loss: 0.1094 - mean_iou: 0.663 - ETA: 40s - loss: 0.1076 - mean_iou: 0.664 - ETA: 38s - loss: 0.1087 - mean_iou: 0.664 - ETA: 36s - loss: 0.1091 - mean_iou: 0.664 - ETA: 35s - loss: 0.1077 - mean_iou: 0.664 - ETA: 33s - loss: 0.1067 - mean_iou: 0.664 - ETA: 31s - loss: 0.1048 - mean_iou: 0.665 - ETA: 30s - loss: 0.1030 - mean_iou: 0.665 - ETA: 28s - loss: 0.1010 - mean_iou: 0.665 - ETA: 26s - loss: 0.1012 - mean_iou: 0.665 - ETA: 24s - loss: 0.1007 - mean_iou: 0.666 - ETA: 23s - loss: 0.1013 - mean_iou: 0.666 - ETA: 21s - loss: 0.1008 - mean_iou: 0.666 - ETA: 19s - loss: 0.1010 - mean_iou: 0.666 - ETA: 18s - loss: 0.1010 - mean_iou: 0.667 - ETA: 16s - loss: 0.1039 - mean_iou: 0.667 - ETA: 14s - loss: 0.1039 - mean_iou: 0.667 - ETA: 13s - loss: 0.1036 - mean_iou: 0.667 - ETA: 11s - loss: 0.1039 - mean_iou: 0.668 - ETA: 9s - loss: 0.1041 - mean_iou: 0.668 - ETA: 8s - loss: 0.1043 - mean_iou: 0.66 - ETA: 6s - loss: 0.1050 - mean_iou: 0.66 - ETA: 4s - loss: 0.1046 - mean_iou: 0.66 - ETA: 2s - loss: 0.1034 - mean_iou: 0.66 - ETA: 1s - loss: 0.1040 - mean_iou: 0.6695
# Epoch 00008: val_loss improved from 0.10619 to 0.10110, saving model to model-dsbowl2018-1.h5
# 603/603 [==============================] - 67s 112ms/step - loss: 0.1032 - mean_iou: 0.6697 - val_loss: 0.1011 - val_mean_iou: 0.6788
# Epoch 9/50
# 592/603 [============================>.] - ETA: 1:04 - loss: 0.1144 - mean_iou: 0.67 - ETA: 1:01 - loss: 0.1145 - mean_iou: 0.68 - ETA: 59s - loss: 0.1153 - mean_iou: 0.6802 - ETA: 57s - loss: 0.1141 - mean_iou: 0.680 - ETA: 55s - loss: 0.1066 - mean_iou: 0.680 - ETA: 54s - loss: 0.1039 - mean_iou: 0.680 - ETA: 52s - loss: 0.1112 - mean_iou: 0.681 - ETA: 50s - loss: 0.1064 - mean_iou: 0.681 - ETA: 48s - loss: 0.1081 - mean_iou: 0.681 - ETA: 47s - loss: 0.1050 - mean_iou: 0.681 - ETA: 45s - loss: 0.1003 - mean_iou: 0.681 - ETA: 43s - loss: 0.0982 - mean_iou: 0.682 - ETA: 41s - loss: 0.1001 - mean_iou: 0.682 - ETA: 40s - loss: 0.0986 - mean_iou: 0.682 - ETA: 38s - loss: 0.0993 - mean_iou: 0.682 - ETA: 36s - loss: 0.1015 - mean_iou: 0.682 - ETA: 35s - loss: 0.0994 - mean_iou: 0.683 - ETA: 33s - loss: 0.1035 - mean_iou: 0.683 - ETA: 31s - loss: 0.1062 - mean_iou: 0.683 - ETA: 30s - loss: 0.1045 - mean_iou: 0.683 - ETA: 28s - loss: 0.1048 - mean_iou: 0.683 - ETA: 26s - loss: 0.1043 - mean_iou: 0.684 - ETA: 25s - loss: 0.1039 - mean_iou: 0.684 - ETA: 23s - loss: 0.1057 - mean_iou: 0.684 - ETA: 21s - loss: 0.1044 - mean_iou: 0.684 - ETA: 19s - loss: 0.1031 - mean_iou: 0.684 - ETA: 18s - loss: 0.1023 - mean_iou: 0.684 - ETA: 16s - loss: 0.1024 - mean_iou: 0.685 - ETA: 14s - loss: 0.1016 - mean_iou: 0.685 - ETA: 13s - loss: 0.1018 - mean_iou: 0.685 - ETA: 11s - loss: 0.1016 - mean_iou: 0.685 - ETA: 9s - loss: 0.1017 - mean_iou: 0.685 - ETA: 7s - loss: 0.1018 - mean_iou: 0.68 - ETA: 6s - loss: 0.1026 - mean_iou: 0.68 - ETA: 4s - loss: 0.1027 - mean_iou: 0.68 - ETA: 2s - loss: 0.1034 - mean_iou: 0.68 - ETA: 1s - loss: 0.1036 - mean_iou: 0.6867
# Epoch 00009: val_loss improved from 0.10110 to 0.09886, saving model to model-dsbowl2018-1.h5
# 603/603 [==============================] - 66s 110ms/step - loss: 0.1030 - mean_iou: 0.6869 - val_loss: 0.0989 - val_mean_iou: 0.6943
# Epoch 10/50
# 592/603 [============================>.] - ETA: 1:01 - loss: 0.0664 - mean_iou: 0.69 - ETA: 59s - loss: 0.0684 - mean_iou: 0.6954 - ETA: 57s - loss: 0.0653 - mean_iou: 0.695 - ETA: 56s - loss: 0.0771 - mean_iou: 0.695 - ETA: 54s - loss: 0.0856 - mean_iou: 0.696 - ETA: 52s - loss: 0.0855 - mean_iou: 0.696 - ETA: 50s - loss: 0.0939 - mean_iou: 0.696 - ETA: 49s - loss: 0.0910 - mean_iou: 0.696 - ETA: 47s - loss: 0.0904 - mean_iou: 0.696 - ETA: 46s - loss: 0.0887 - mean_iou: 0.696 - ETA: 44s - loss: 0.0887 - mean_iou: 0.697 - ETA: 42s - loss: 0.0911 - mean_iou: 0.697 - ETA: 41s - loss: 0.0929 - mean_iou: 0.697 - ETA: 39s - loss: 0.0931 - mean_iou: 0.697 - ETA: 37s - loss: 0.0945 - mean_iou: 0.697 - ETA: 36s - loss: 0.0932 - mean_iou: 0.697 - ETA: 34s - loss: 0.0919 - mean_iou: 0.698 - ETA: 32s - loss: 0.0912 - mean_iou: 0.698 - ETA: 31s - loss: 0.0906 - mean_iou: 0.698 - ETA: 29s - loss: 0.0943 - mean_iou: 0.698 - ETA: 27s - loss: 0.0940 - mean_iou: 0.698 - ETA: 26s - loss: 0.0937 - mean_iou: 0.698 - ETA: 24s - loss: 0.0925 - mean_iou: 0.699 - ETA: 22s - loss: 0.0910 - mean_iou: 0.699 - ETA: 21s - loss: 0.0916 - mean_iou: 0.699 - ETA: 19s - loss: 0.0930 - mean_iou: 0.699 - ETA: 17s - loss: 0.0932 - mean_iou: 0.699 - ETA: 16s - loss: 0.0933 - mean_iou: 0.699 - ETA: 14s - loss: 0.0934 - mean_iou: 0.700 - ETA: 12s - loss: 0.0939 - mean_iou: 0.700 - ETA: 11s - loss: 0.0934 - mean_iou: 0.700 - ETA: 9s - loss: 0.0953 - mean_iou: 0.700 - ETA: 7s - loss: 0.0942 - mean_iou: 0.70 - ETA: 6s - loss: 0.0932 - mean_iou: 0.70 - ETA: 4s - loss: 0.0939 - mean_iou: 0.70 - ETA: 2s - loss: 0.0935 - mean_iou: 0.70 - ETA: 1s - loss: 0.0953 - mean_iou: 0.7013
# Epoch 00010: val_loss did not improve
# 603/603 [==============================] - 65s 108ms/step - loss: 0.0956 - mean_iou: 0.7014 - val_loss: 0.1037 - val_mean_iou: 0.7079
# Epoch 11/50
# 592/603 [============================>.] - ETA: 1:00 - loss: 0.1020 - mean_iou: 0.70 - ETA: 59s - loss: 0.0999 - mean_iou: 0.7087 - ETA: 57s - loss: 0.1032 - mean_iou: 0.708 - ETA: 55s - loss: 0.1007 - mean_iou: 0.708 - ETA: 54s - loss: 0.0996 - mean_iou: 0.709 - ETA: 52s - loss: 0.0972 - mean_iou: 0.709 - ETA: 50s - loss: 0.0939 - mean_iou: 0.709 - ETA: 49s - loss: 0.0896 - mean_iou: 0.709 - ETA: 47s - loss: 0.0950 - mean_iou: 0.709 - ETA: 46s - loss: 0.0907 - mean_iou: 0.709 - ETA: 44s - loss: 0.0920 - mean_iou: 0.710 - ETA: 42s - loss: 0.0919 - mean_iou: 0.710 - ETA: 41s - loss: 0.0945 - mean_iou: 0.710 - ETA: 39s - loss: 0.0964 - mean_iou: 0.710 - ETA: 37s - loss: 0.0976 - mean_iou: 0.710 - ETA: 36s - loss: 0.0948 - mean_iou: 0.710 - ETA: 34s - loss: 0.0980 - mean_iou: 0.710 - ETA: 32s - loss: 0.0983 - mean_iou: 0.711 - ETA: 31s - loss: 0.0985 - mean_iou: 0.711 - ETA: 29s - loss: 0.1003 - mean_iou: 0.711 - ETA: 27s - loss: 0.0997 - mean_iou: 0.711 - ETA: 26s - loss: 0.0999 - mean_iou: 0.711 - ETA: 24s - loss: 0.1004 - mean_iou: 0.711 - ETA: 22s - loss: 0.0988 - mean_iou: 0.711 - ETA: 21s - loss: 0.0985 - mean_iou: 0.711 - ETA: 19s - loss: 0.0988 - mean_iou: 0.712 - ETA: 17s - loss: 0.1000 - mean_iou: 0.712 - ETA: 16s - loss: 0.0996 - mean_iou: 0.712 - ETA: 14s - loss: 0.0994 - mean_iou: 0.712 - ETA: 12s - loss: 0.0991 - mean_iou: 0.712 - ETA: 11s - loss: 0.0994 - mean_iou: 0.712 - ETA: 9s - loss: 0.0988 - mean_iou: 0.712 - ETA: 7s - loss: 0.0989 - mean_iou: 0.71 - ETA: 6s - loss: 0.0974 - mean_iou: 0.71 - ETA: 4s - loss: 0.0967 - mean_iou: 0.71 - ETA: 2s - loss: 0.0960 - mean_iou: 0.71 - ETA: 1s - loss: 0.0948 - mean_iou: 0.7134
# Epoch 00011: val_loss improved from 0.09886 to 0.09722, saving model to model-dsbowl2018-1.h5
# 603/603 [==============================] - 65s 108ms/step - loss: 0.0958 - mean_iou: 0.7135 - val_loss: 0.0972 - val_mean_iou: 0.7189
# Epoch 12/50
# 592/603 [============================>.] - ETA: 1:00 - loss: 0.0783 - mean_iou: 0.71 - ETA: 59s - loss: 0.0899 - mean_iou: 0.7195 - ETA: 57s - loss: 0.0919 - mean_iou: 0.719 - ETA: 55s - loss: 0.0883 - mean_iou: 0.719 - ETA: 54s - loss: 0.0928 - mean_iou: 0.719 - ETA: 52s - loss: 0.0895 - mean_iou: 0.720 - ETA: 50s - loss: 0.0906 - mean_iou: 0.720 - ETA: 49s - loss: 0.0899 - mean_iou: 0.720 - ETA: 47s - loss: 0.0898 - mean_iou: 0.720 - ETA: 45s - loss: 0.0885 - mean_iou: 0.720 - ETA: 44s - loss: 0.0870 - mean_iou: 0.720 - ETA: 42s - loss: 0.0892 - mean_iou: 0.720 - ETA: 41s - loss: 0.0907 - mean_iou: 0.720 - ETA: 39s - loss: 0.0905 - mean_iou: 0.721 - ETA: 37s - loss: 0.0903 - mean_iou: 0.721 - ETA: 36s - loss: 0.0906 - mean_iou: 0.721 - ETA: 34s - loss: 0.0931 - mean_iou: 0.721 - ETA: 32s - loss: 0.0931 - mean_iou: 0.721 - ETA: 31s - loss: 0.0932 - mean_iou: 0.721 - ETA: 29s - loss: 0.0928 - mean_iou: 0.721 - ETA: 27s - loss: 0.0929 - mean_iou: 0.721 - ETA: 26s - loss: 0.0951 - mean_iou: 0.721 - ETA: 24s - loss: 0.0960 - mean_iou: 0.722 - ETA: 22s - loss: 0.0947 - mean_iou: 0.722 - ETA: 21s - loss: 0.0947 - mean_iou: 0.722 - ETA: 19s - loss: 0.0939 - mean_iou: 0.722 - ETA: 17s - loss: 0.0941 - mean_iou: 0.722 - ETA: 16s - loss: 0.0945 - mean_iou: 0.722 - ETA: 14s - loss: 0.0958 - mean_iou: 0.722 - ETA: 12s - loss: 0.0962 - mean_iou: 0.722 - ETA: 11s - loss: 0.0961 - mean_iou: 0.723 - ETA: 9s - loss: 0.0952 - mean_iou: 0.723 - ETA: 7s - loss: 0.0951 - mean_iou: 0.72 - ETA: 6s - loss: 0.0946 - mean_iou: 0.72 - ETA: 4s - loss: 0.0950 - mean_iou: 0.72 - ETA: 2s - loss: 0.0943 - mean_iou: 0.72 - ETA: 1s - loss: 0.0940 - mean_iou: 0.7238
# Epoch 00012: val_loss improved from 0.09722 to 0.08960, saving model to model-dsbowl2018-1.h5
# 603/603 [==============================] - 65s 109ms/step - loss: 0.0930 - mean_iou: 0.7238 - val_loss: 0.0896 - val_mean_iou: 0.7286
# Epoch 13/50
# 592/603 [============================>.] - ETA: 1:01 - loss: 0.0664 - mean_iou: 0.72 - ETA: 59s - loss: 0.0788 - mean_iou: 0.7292 - ETA: 57s - loss: 0.0875 - mean_iou: 0.729 - ETA: 56s - loss: 0.0862 - mean_iou: 0.729 - ETA: 54s - loss: 0.0933 - mean_iou: 0.729 - ETA: 52s - loss: 0.0968 - mean_iou: 0.729 - ETA: 51s - loss: 0.0925 - mean_iou: 0.729 - ETA: 49s - loss: 0.0902 - mean_iou: 0.729 - ETA: 47s - loss: 0.0897 - mean_iou: 0.729 - ETA: 46s - loss: 0.0869 - mean_iou: 0.730 - ETA: 44s - loss: 0.0860 - mean_iou: 0.730 - ETA: 42s - loss: 0.0879 - mean_iou: 0.730 - ETA: 41s - loss: 0.0875 - mean_iou: 0.730 - ETA: 39s - loss: 0.0864 - mean_iou: 0.730 - ETA: 37s - loss: 0.0872 - mean_iou: 0.730 - ETA: 36s - loss: 0.0873 - mean_iou: 0.730 - ETA: 34s - loss: 0.0869 - mean_iou: 0.730 - ETA: 32s - loss: 0.0871 - mean_iou: 0.730 - ETA: 31s - loss: 0.0866 - mean_iou: 0.731 - ETA: 29s - loss: 0.0892 - mean_iou: 0.731 - ETA: 27s - loss: 0.0884 - mean_iou: 0.731 - ETA: 26s - loss: 0.0873 - mean_iou: 0.731 - ETA: 24s - loss: 0.0870 - mean_iou: 0.731 - ETA: 22s - loss: 0.0880 - mean_iou: 0.731 - ETA: 21s - loss: 0.0872 - mean_iou: 0.731 - ETA: 19s - loss: 0.0871 - mean_iou: 0.731 - ETA: 17s - loss: 0.0872 - mean_iou: 0.731 - ETA: 16s - loss: 0.0875 - mean_iou: 0.732 - ETA: 14s - loss: 0.0881 - mean_iou: 0.732 - ETA: 12s - loss: 0.0878 - mean_iou: 0.732 - ETA: 11s - loss: 0.0878 - mean_iou: 0.732 - ETA: 9s - loss: 0.0887 - mean_iou: 0.732 - ETA: 7s - loss: 0.0883 - mean_iou: 0.73 - ETA: 6s - loss: 0.0887 - mean_iou: 0.73 - ETA: 4s - loss: 0.0883 - mean_iou: 0.73 - ETA: 2s - loss: 0.0880 - mean_iou: 0.73 - ETA: 1s - loss: 0.0877 - mean_iou: 0.7329
# Epoch 00013: val_loss improved from 0.08960 to 0.08616, saving model to model-dsbowl2018-1.h5
# 603/603 [==============================] - 65s 107ms/step - loss: 0.0879 - mean_iou: 0.7330 - val_loss: 0.0862 - val_mean_iou: 0.7371
# Epoch 14/50
# 592/603 [============================>.] - ETA: 59s - loss: 0.0714 - mean_iou: 0.737 - ETA: 57s - loss: 0.0839 - mean_iou: 0.737 - ETA: 56s - loss: 0.0775 - mean_iou: 0.737 - ETA: 54s - loss: 0.0774 - mean_iou: 0.737 - ETA: 53s - loss: 0.0775 - mean_iou: 0.738 - ETA: 51s - loss: 0.0786 - mean_iou: 0.738 - ETA: 49s - loss: 0.0784 - mean_iou: 0.738 - ETA: 48s - loss: 0.0777 - mean_iou: 0.738 - ETA: 46s - loss: 0.0770 - mean_iou: 0.738 - ETA: 44s - loss: 0.0766 - mean_iou: 0.738 - ETA: 43s - loss: 0.0761 - mean_iou: 0.738 - ETA: 41s - loss: 0.0770 - mean_iou: 0.738 - ETA: 40s - loss: 0.0759 - mean_iou: 0.738 - ETA: 38s - loss: 0.0776 - mean_iou: 0.739 - ETA: 36s - loss: 0.0770 - mean_iou: 0.739 - ETA: 35s - loss: 0.0781 - mean_iou: 0.739 - ETA: 33s - loss: 0.0773 - mean_iou: 0.739 - ETA: 32s - loss: 0.0773 - mean_iou: 0.739 - ETA: 30s - loss: 0.0781 - mean_iou: 0.739 - ETA: 28s - loss: 0.0783 - mean_iou: 0.739 - ETA: 27s - loss: 0.0787 - mean_iou: 0.739 - ETA: 25s - loss: 0.0812 - mean_iou: 0.739 - ETA: 23s - loss: 0.0823 - mean_iou: 0.739 - ETA: 22s - loss: 0.0819 - mean_iou: 0.740 - ETA: 20s - loss: 0.0838 - mean_iou: 0.740 - ETA: 19s - loss: 0.0845 - mean_iou: 0.740 - ETA: 17s - loss: 0.0855 - mean_iou: 0.740 - ETA: 15s - loss: 0.0851 - mean_iou: 0.740 - ETA: 14s - loss: 0.0859 - mean_iou: 0.740 - ETA: 12s - loss: 0.0856 - mean_iou: 0.740 - ETA: 10s - loss: 0.0853 - mean_iou: 0.740 - ETA: 9s - loss: 0.0850 - mean_iou: 0.740 - ETA: 7s - loss: 0.0852 - mean_iou: 0.74 - ETA: 6s - loss: 0.0843 - mean_iou: 0.74 - ETA: 4s - loss: 0.0859 - mean_iou: 0.74 - ETA: 2s - loss: 0.0857 - mean_iou: 0.74 - ETA: 1s - loss: 0.0853 - mean_iou: 0.7412
# Epoch 00014: val_loss did not improve
# 603/603 [==============================] - 64s 106ms/step - loss: 0.0856 - mean_iou: 0.7412 - val_loss: 0.0864 - val_mean_iou: 0.7449
# Epoch 15/50
# 592/603 [============================>.] - ETA: 59s - loss: 0.1047 - mean_iou: 0.745 - ETA: 58s - loss: 0.0997 - mean_iou: 0.745 - ETA: 56s - loss: 0.0872 - mean_iou: 0.745 - ETA: 55s - loss: 0.0942 - mean_iou: 0.745 - ETA: 53s - loss: 0.0909 - mean_iou: 0.745 - ETA: 51s - loss: 0.0917 - mean_iou: 0.745 - ETA: 50s - loss: 0.0869 - mean_iou: 0.745 - ETA: 48s - loss: 0.0883 - mean_iou: 0.746 - ETA: 46s - loss: 0.0879 - mean_iou: 0.746 - ETA: 45s - loss: 0.0871 - mean_iou: 0.746 - ETA: 43s - loss: 0.0877 - mean_iou: 0.746 - ETA: 41s - loss: 0.0859 - mean_iou: 0.746 - ETA: 40s - loss: 0.0909 - mean_iou: 0.746 - ETA: 38s - loss: 0.0882 - mean_iou: 0.746 - ETA: 36s - loss: 0.0873 - mean_iou: 0.746 - ETA: 35s - loss: 0.0872 - mean_iou: 0.746 - ETA: 33s - loss: 0.0883 - mean_iou: 0.746 - ETA: 32s - loss: 0.0882 - mean_iou: 0.746 - ETA: 30s - loss: 0.0879 - mean_iou: 0.746 - ETA: 28s - loss: 0.0865 - mean_iou: 0.747 - ETA: 27s - loss: 0.0859 - mean_iou: 0.747 - ETA: 25s - loss: 0.0854 - mean_iou: 0.747 - ETA: 23s - loss: 0.0856 - mean_iou: 0.747 - ETA: 22s - loss: 0.0841 - mean_iou: 0.747 - ETA: 20s - loss: 0.0854 - mean_iou: 0.747 - ETA: 19s - loss: 0.0855 - mean_iou: 0.747 - ETA: 17s - loss: 0.0853 - mean_iou: 0.747 - ETA: 15s - loss: 0.0852 - mean_iou: 0.747 - ETA: 14s - loss: 0.0848 - mean_iou: 0.747 - ETA: 12s - loss: 0.0858 - mean_iou: 0.747 - ETA: 10s - loss: 0.0858 - mean_iou: 0.747 - ETA: 9s - loss: 0.0854 - mean_iou: 0.748 - ETA: 7s - loss: 0.0855 - mean_iou: 0.74 - ETA: 6s - loss: 0.0856 - mean_iou: 0.74 - ETA: 4s - loss: 0.0856 - mean_iou: 0.74 - ETA: 2s - loss: 0.0851 - mean_iou: 0.74 - ETA: 1s - loss: 0.0862 - mean_iou: 0.7484
# Epoch 00015: val_loss improved from 0.08616 to 0.08380, saving model to model-dsbowl2018-1.h5
# 603/603 [==============================] - 65s 108ms/step - loss: 0.0855 - mean_iou: 0.7484 - val_loss: 0.0838 - val_mean_iou: 0.7518
# Epoch 16/50
# 592/603 [============================>.] - ETA: 1:07 - loss: 0.0892 - mean_iou: 0.75 - ETA: 1:04 - loss: 0.0799 - mean_iou: 0.75 - ETA: 1:03 - loss: 0.0963 - mean_iou: 0.75 - ETA: 1:00 - loss: 0.0932 - mean_iou: 0.75 - ETA: 58s - loss: 0.0925 - mean_iou: 0.7525 - ETA: 56s - loss: 0.0886 - mean_iou: 0.752 - ETA: 55s - loss: 0.0881 - mean_iou: 0.752 - ETA: 53s - loss: 0.0895 - mean_iou: 0.752 - ETA: 51s - loss: 0.0878 - mean_iou: 0.752 - ETA: 49s - loss: 0.0873 - mean_iou: 0.752 - ETA: 47s - loss: 0.0856 - mean_iou: 0.752 - ETA: 45s - loss: 0.0838 - mean_iou: 0.753 - ETA: 43s - loss: 0.0827 - mean_iou: 0.753 - ETA: 41s - loss: 0.0841 - mean_iou: 0.753 - ETA: 39s - loss: 0.0842 - mean_iou: 0.753 - ETA: 37s - loss: 0.0822 - mean_iou: 0.753 - ETA: 36s - loss: 0.0838 - mean_iou: 0.753 - ETA: 34s - loss: 0.0828 - mean_iou: 0.753 - ETA: 32s - loss: 0.0835 - mean_iou: 0.753 - ETA: 31s - loss: 0.0827 - mean_iou: 0.753 - ETA: 29s - loss: 0.0818 - mean_iou: 0.753 - ETA: 27s - loss: 0.0823 - mean_iou: 0.753 - ETA: 25s - loss: 0.0827 - mean_iou: 0.753 - ETA: 23s - loss: 0.0821 - mean_iou: 0.753 - ETA: 22s - loss: 0.0836 - mean_iou: 0.753 - ETA: 20s - loss: 0.0826 - mean_iou: 0.754 - ETA: 18s - loss: 0.0823 - mean_iou: 0.754 - ETA: 16s - loss: 0.0826 - mean_iou: 0.754 - ETA: 15s - loss: 0.0822 - mean_iou: 0.754 - ETA: 13s - loss: 0.0812 - mean_iou: 0.754 - ETA: 11s - loss: 0.0809 - mean_iou: 0.754 - ETA: 9s - loss: 0.0809 - mean_iou: 0.754 - ETA: 8s - loss: 0.0810 - mean_iou: 0.75 - ETA: 6s - loss: 0.0815 - mean_iou: 0.75 - ETA: 4s - loss: 0.0812 - mean_iou: 0.75 - ETA: 2s - loss: 0.0814 - mean_iou: 0.75 - ETA: 1s - loss: 0.0805 - mean_iou: 0.7549
# Epoch 00016: val_loss improved from 0.08380 to 0.08264, saving model to model-dsbowl2018-1.h5
# 603/603 [==============================] - 68s 113ms/step - loss: 0.0815 - mean_iou: 0.7549 - val_loss: 0.0826 - val_mean_iou: 0.7579
# Epoch 17/50
# 592/603 [============================>.] - ETA: 1:01 - loss: 0.0979 - mean_iou: 0.75 - ETA: 1:00 - loss: 0.0911 - mean_iou: 0.75 - ETA: 58s - loss: 0.0828 - mean_iou: 0.7584 - ETA: 57s - loss: 0.0846 - mean_iou: 0.758 - ETA: 55s - loss: 0.0806 - mean_iou: 0.758 - ETA: 53s - loss: 0.0829 - mean_iou: 0.758 - ETA: 52s - loss: 0.0825 - mean_iou: 0.758 - ETA: 50s - loss: 0.0797 - mean_iou: 0.758 - ETA: 48s - loss: 0.0823 - mean_iou: 0.758 - ETA: 47s - loss: 0.0805 - mean_iou: 0.758 - ETA: 45s - loss: 0.0784 - mean_iou: 0.758 - ETA: 43s - loss: 0.0787 - mean_iou: 0.759 - ETA: 42s - loss: 0.0800 - mean_iou: 0.759 - ETA: 40s - loss: 0.0791 - mean_iou: 0.759 - ETA: 38s - loss: 0.0792 - mean_iou: 0.759 - ETA: 37s - loss: 0.0797 - mean_iou: 0.759 - ETA: 35s - loss: 0.0784 - mean_iou: 0.759 - ETA: 33s - loss: 0.0775 - mean_iou: 0.759 - ETA: 31s - loss: 0.0776 - mean_iou: 0.759 - ETA: 30s - loss: 0.0779 - mean_iou: 0.759 - ETA: 28s - loss: 0.0767 - mean_iou: 0.759 - ETA: 26s - loss: 0.0748 - mean_iou: 0.759 - ETA: 25s - loss: 0.0751 - mean_iou: 0.759 - ETA: 23s - loss: 0.0734 - mean_iou: 0.759 - ETA: 21s - loss: 0.0733 - mean_iou: 0.760 - ETA: 20s - loss: 0.0741 - mean_iou: 0.760 - ETA: 18s - loss: 0.0738 - mean_iou: 0.760 - ETA: 16s - loss: 0.0732 - mean_iou: 0.760 - ETA: 15s - loss: 0.0743 - mean_iou: 0.760 - ETA: 13s - loss: 0.0741 - mean_iou: 0.760 - ETA: 11s - loss: 0.0742 - mean_iou: 0.760 - ETA: 9s - loss: 0.0749 - mean_iou: 0.760 - ETA: 8s - loss: 0.0768 - mean_iou: 0.76 - ETA: 6s - loss: 0.0771 - mean_iou: 0.76 - ETA: 4s - loss: 0.0780 - mean_iou: 0.76 - ETA: 2s - loss: 0.0792 - mean_iou: 0.76 - ETA: 1s - loss: 0.0794 - mean_iou: 0.7608
# Epoch 00017: val_loss did not improve
# 603/603 [==============================] - 68s 113ms/step - loss: 0.0793 - mean_iou: 0.7609 - val_loss: 0.0834 - val_mean_iou: 0.7636
# Epoch 18/50
# 592/603 [============================>.] - ETA: 1:02 - loss: 0.1086 - mean_iou: 0.76 - ETA: 1:00 - loss: 0.0825 - mean_iou: 0.76 - ETA: 59s - loss: 0.0864 - mean_iou: 0.7640 - ETA: 58s - loss: 0.0823 - mean_iou: 0.764 - ETA: 56s - loss: 0.0804 - mean_iou: 0.764 - ETA: 55s - loss: 0.0807 - mean_iou: 0.764 - ETA: 53s - loss: 0.0835 - mean_iou: 0.764 - ETA: 51s - loss: 0.0795 - mean_iou: 0.764 - ETA: 49s - loss: 0.0760 - mean_iou: 0.764 - ETA: 47s - loss: 0.0753 - mean_iou: 0.764 - ETA: 45s - loss: 0.0733 - mean_iou: 0.764 - ETA: 44s - loss: 0.0733 - mean_iou: 0.764 - ETA: 42s - loss: 0.0725 - mean_iou: 0.764 - ETA: 41s - loss: 0.0708 - mean_iou: 0.764 - ETA: 39s - loss: 0.0729 - mean_iou: 0.764 - ETA: 37s - loss: 0.0741 - mean_iou: 0.764 - ETA: 35s - loss: 0.0744 - mean_iou: 0.765 - ETA: 33s - loss: 0.0738 - mean_iou: 0.765 - ETA: 31s - loss: 0.0743 - mean_iou: 0.765 - ETA: 30s - loss: 0.0740 - mean_iou: 0.765 - ETA: 28s - loss: 0.0739 - mean_iou: 0.765 - ETA: 26s - loss: 0.0748 - mean_iou: 0.765 - ETA: 24s - loss: 0.0747 - mean_iou: 0.765 - ETA: 23s - loss: 0.0744 - mean_iou: 0.765 - ETA: 21s - loss: 0.0740 - mean_iou: 0.765 - ETA: 19s - loss: 0.0747 - mean_iou: 0.765 - ETA: 18s - loss: 0.0772 - mean_iou: 0.765 - ETA: 16s - loss: 0.0783 - mean_iou: 0.765 - ETA: 14s - loss: 0.0789 - mean_iou: 0.765 - ETA: 12s - loss: 0.0786 - mean_iou: 0.765 - ETA: 11s - loss: 0.0781 - mean_iou: 0.765 - ETA: 9s - loss: 0.0784 - mean_iou: 0.766 - ETA: 7s - loss: 0.0787 - mean_iou: 0.76 - ETA: 6s - loss: 0.0791 - mean_iou: 0.76 - ETA: 4s - loss: 0.0793 - mean_iou: 0.76 - ETA: 2s - loss: 0.0789 - mean_iou: 0.76 - ETA: 1s - loss: 0.0795 - mean_iou: 0.7663
# Epoch 00018: val_loss did not improve
# 603/603 [==============================] - 66s 109ms/step - loss: 0.0797 - mean_iou: 0.7663 - val_loss: 0.0852 - val_mean_iou: 0.7685
# Epoch 19/50
# 592/603 [============================>.] - ETA: 1:00 - loss: 0.0517 - mean_iou: 0.76 - ETA: 58s - loss: 0.0538 - mean_iou: 0.7689 - ETA: 57s - loss: 0.0636 - mean_iou: 0.768 - ETA: 55s - loss: 0.0926 - mean_iou: 0.769 - ETA: 53s - loss: 0.0877 - mean_iou: 0.769 - ETA: 52s - loss: 0.0856 - mean_iou: 0.769 - ETA: 50s - loss: 0.0897 - mean_iou: 0.769 - ETA: 48s - loss: 0.0858 - mean_iou: 0.769 - ETA: 47s - loss: 0.0845 - mean_iou: 0.769 - ETA: 45s - loss: 0.0821 - mean_iou: 0.769 - ETA: 43s - loss: 0.0824 - mean_iou: 0.769 - ETA: 42s - loss: 0.0816 - mean_iou: 0.769 - ETA: 40s - loss: 0.0807 - mean_iou: 0.769 - ETA: 38s - loss: 0.0811 - mean_iou: 0.769 - ETA: 37s - loss: 0.0818 - mean_iou: 0.769 - ETA: 35s - loss: 0.0828 - mean_iou: 0.769 - ETA: 33s - loss: 0.0828 - mean_iou: 0.769 - ETA: 32s - loss: 0.0846 - mean_iou: 0.769 - ETA: 30s - loss: 0.0840 - mean_iou: 0.769 - ETA: 28s - loss: 0.0848 - mean_iou: 0.769 - ETA: 27s - loss: 0.0848 - mean_iou: 0.769 - ETA: 25s - loss: 0.0847 - mean_iou: 0.769 - ETA: 24s - loss: 0.0835 - mean_iou: 0.770 - ETA: 22s - loss: 0.0842 - mean_iou: 0.770 - ETA: 20s - loss: 0.0845 - mean_iou: 0.770 - ETA: 19s - loss: 0.0840 - mean_iou: 0.770 - ETA: 17s - loss: 0.0832 - mean_iou: 0.770 - ETA: 15s - loss: 0.0824 - mean_iou: 0.770 - ETA: 14s - loss: 0.0815 - mean_iou: 0.770 - ETA: 12s - loss: 0.0815 - mean_iou: 0.770 - ETA: 10s - loss: 0.0816 - mean_iou: 0.770 - ETA: 9s - loss: 0.0810 - mean_iou: 0.770 - ETA: 7s - loss: 0.0803 - mean_iou: 0.77 - ETA: 6s - loss: 0.0806 - mean_iou: 0.77 - ETA: 4s - loss: 0.0801 - mean_iou: 0.77 - ETA: 2s - loss: 0.0800 - mean_iou: 0.77 - ETA: 1s - loss: 0.0793 - mean_iou: 0.7708
# Epoch 00019: val_loss improved from 0.08264 to 0.07757, saving model to model-dsbowl2018-1.h5
# 603/603 [==============================] - 64s 107ms/step - loss: 0.0793 - mean_iou: 0.7708 - val_loss: 0.0776 - val_mean_iou: 0.7732
# Epoch 20/50
# 592/603 [============================>.] - ETA: 1:00 - loss: 0.0838 - mean_iou: 0.77 - ETA: 58s - loss: 0.0882 - mean_iou: 0.7735 - ETA: 56s - loss: 0.0826 - mean_iou: 0.773 - ETA: 54s - loss: 0.0772 - mean_iou: 0.773 - ETA: 53s - loss: 0.0742 - mean_iou: 0.773 - ETA: 51s - loss: 0.0728 - mean_iou: 0.773 - ETA: 50s - loss: 0.0748 - mean_iou: 0.773 - ETA: 48s - loss: 0.0738 - mean_iou: 0.773 - ETA: 46s - loss: 0.0748 - mean_iou: 0.773 - ETA: 45s - loss: 0.0804 - mean_iou: 0.774 - ETA: 43s - loss: 0.0823 - mean_iou: 0.774 - ETA: 42s - loss: 0.0822 - mean_iou: 0.774 - ETA: 40s - loss: 0.0815 - mean_iou: 0.774 - ETA: 38s - loss: 0.0792 - mean_iou: 0.774 - ETA: 37s - loss: 0.0809 - mean_iou: 0.774 - ETA: 35s - loss: 0.0808 - mean_iou: 0.774 - ETA: 33s - loss: 0.0814 - mean_iou: 0.774 - ETA: 32s - loss: 0.0798 - mean_iou: 0.774 - ETA: 30s - loss: 0.0773 - mean_iou: 0.774 - ETA: 28s - loss: 0.0770 - mean_iou: 0.774 - ETA: 27s - loss: 0.0774 - mean_iou: 0.774 - ETA: 25s - loss: 0.0768 - mean_iou: 0.774 - ETA: 24s - loss: 0.0768 - mean_iou: 0.774 - ETA: 22s - loss: 0.0765 - mean_iou: 0.774 - ETA: 20s - loss: 0.0779 - mean_iou: 0.774 - ETA: 19s - loss: 0.0781 - mean_iou: 0.774 - ETA: 17s - loss: 0.0770 - mean_iou: 0.774 - ETA: 15s - loss: 0.0774 - mean_iou: 0.774 - ETA: 14s - loss: 0.0760 - mean_iou: 0.774 - ETA: 12s - loss: 0.0765 - mean_iou: 0.775 - ETA: 10s - loss: 0.0757 - mean_iou: 0.775 - ETA: 9s - loss: 0.0765 - mean_iou: 0.775 - ETA: 7s - loss: 0.0772 - mean_iou: 0.77 - ETA: 6s - loss: 0.0771 - mean_iou: 0.77 - ETA: 4s - loss: 0.0781 - mean_iou: 0.77 - ETA: 2s - loss: 0.0779 - mean_iou: 0.77 - ETA: 1s - loss: 0.0778 - mean_iou: 0.7753
# Epoch 00020: val_loss improved from 0.07757 to 0.07726, saving model to model-dsbowl2018-1.h5
# 603/603 [==============================] - 64s 106ms/step - loss: 0.0775 - mean_iou: 0.7754 - val_loss: 0.0773 - val_mean_iou: 0.7775
# Epoch 21/50
# 592/603 [============================>.] - ETA: 59s - loss: 0.0690 - mean_iou: 0.777 - ETA: 58s - loss: 0.0720 - mean_iou: 0.777 - ETA: 56s - loss: 0.0798 - mean_iou: 0.777 - ETA: 55s - loss: 0.0738 - mean_iou: 0.777 - ETA: 53s - loss: 0.0689 - mean_iou: 0.777 - ETA: 51s - loss: 0.0708 - mean_iou: 0.777 - ETA: 50s - loss: 0.0701 - mean_iou: 0.778 - ETA: 48s - loss: 0.0702 - mean_iou: 0.778 - ETA: 46s - loss: 0.0733 - mean_iou: 0.778 - ETA: 45s - loss: 0.0752 - mean_iou: 0.778 - ETA: 43s - loss: 0.0755 - mean_iou: 0.778 - ETA: 42s - loss: 0.0751 - mean_iou: 0.778 - ETA: 40s - loss: 0.0732 - mean_iou: 0.778 - ETA: 38s - loss: 0.0779 - mean_iou: 0.778 - ETA: 37s - loss: 0.0797 - mean_iou: 0.778 - ETA: 35s - loss: 0.0795 - mean_iou: 0.778 - ETA: 33s - loss: 0.0785 - mean_iou: 0.778 - ETA: 32s - loss: 0.0782 - mean_iou: 0.778 - ETA: 30s - loss: 0.0797 - mean_iou: 0.778 - ETA: 28s - loss: 0.0780 - mean_iou: 0.778 - ETA: 27s - loss: 0.0801 - mean_iou: 0.778 - ETA: 25s - loss: 0.0794 - mean_iou: 0.778 - ETA: 24s - loss: 0.0784 - mean_iou: 0.778 - ETA: 22s - loss: 0.0774 - mean_iou: 0.778 - ETA: 20s - loss: 0.0774 - mean_iou: 0.778 - ETA: 19s - loss: 0.0773 - mean_iou: 0.778 - ETA: 17s - loss: 0.0771 - mean_iou: 0.778 - ETA: 15s - loss: 0.0771 - mean_iou: 0.778 - ETA: 14s - loss: 0.0778 - mean_iou: 0.779 - ETA: 12s - loss: 0.0781 - mean_iou: 0.779 - ETA: 10s - loss: 0.0780 - mean_iou: 0.779 - ETA: 9s - loss: 0.0780 - mean_iou: 0.779 - ETA: 7s - loss: 0.0773 - mean_iou: 0.77 - ETA: 6s - loss: 0.0770 - mean_iou: 0.77 - ETA: 4s - loss: 0.0765 - mean_iou: 0.77 - ETA: 2s - loss: 0.0775 - mean_iou: 0.77 - ETA: 1s - loss: 0.0769 - mean_iou: 0.7793
# Epoch 00021: val_loss did not improve
# 603/603 [==============================] - 64s 106ms/step - loss: 0.0769 - mean_iou: 0.7794 - val_loss: 0.0911 - val_mean_iou: 0.7812
# Epoch 22/50
# 592/603 [============================>.] - ETA: 59s - loss: 0.0496 - mean_iou: 0.781 - ETA: 58s - loss: 0.0534 - mean_iou: 0.781 - ETA: 56s - loss: 0.0582 - mean_iou: 0.781 - ETA: 54s - loss: 0.0738 - mean_iou: 0.781 - ETA: 53s - loss: 0.0703 - mean_iou: 0.781 - ETA: 52s - loss: 0.0713 - mean_iou: 0.781 - ETA: 50s - loss: 0.0722 - mean_iou: 0.781 - ETA: 48s - loss: 0.0703 - mean_iou: 0.781 - ETA: 47s - loss: 0.0725 - mean_iou: 0.781 - ETA: 45s - loss: 0.0727 - mean_iou: 0.781 - ETA: 43s - loss: 0.0744 - mean_iou: 0.781 - ETA: 42s - loss: 0.0739 - mean_iou: 0.781 - ETA: 40s - loss: 0.0739 - mean_iou: 0.781 - ETA: 38s - loss: 0.0778 - mean_iou: 0.782 - ETA: 37s - loss: 0.0784 - mean_iou: 0.782 - ETA: 35s - loss: 0.0827 - mean_iou: 0.782 - ETA: 33s - loss: 0.0843 - mean_iou: 0.782 - ETA: 32s - loss: 0.0826 - mean_iou: 0.782 - ETA: 30s - loss: 0.0817 - mean_iou: 0.782 - ETA: 29s - loss: 0.0811 - mean_iou: 0.782 - ETA: 27s - loss: 0.0811 - mean_iou: 0.782 - ETA: 25s - loss: 0.0807 - mean_iou: 0.782 - ETA: 24s - loss: 0.0804 - mean_iou: 0.782 - ETA: 22s - loss: 0.0803 - mean_iou: 0.782 - ETA: 20s - loss: 0.0793 - mean_iou: 0.782 - ETA: 19s - loss: 0.0808 - mean_iou: 0.782 - ETA: 17s - loss: 0.0810 - mean_iou: 0.782 - ETA: 15s - loss: 0.0816 - mean_iou: 0.782 - ETA: 14s - loss: 0.0806 - mean_iou: 0.782 - ETA: 12s - loss: 0.0809 - mean_iou: 0.782 - ETA: 10s - loss: 0.0803 - mean_iou: 0.782 - ETA: 9s - loss: 0.0800 - mean_iou: 0.782 - ETA: 7s - loss: 0.0796 - mean_iou: 0.78 - ETA: 6s - loss: 0.0792 - mean_iou: 0.78 - ETA: 4s - loss: 0.0792 - mean_iou: 0.78 - ETA: 2s - loss: 0.0801 - mean_iou: 0.78 - ETA: 1s - loss: 0.0802 - mean_iou: 0.7829
# Epoch 00022: val_loss improved from 0.07726 to 0.07637, saving model to model-dsbowl2018-1.h5
# 603/603 [==============================] - 64s 107ms/step - loss: 0.0798 - mean_iou: 0.7829 - val_loss: 0.0764 - val_mean_iou: 0.7846
# Epoch 23/50
# 592/603 [============================>.] - ETA: 59s - loss: 0.0832 - mean_iou: 0.784 - ETA: 58s - loss: 0.0848 - mean_iou: 0.784 - ETA: 56s - loss: 0.0863 - mean_iou: 0.784 - ETA: 55s - loss: 0.0860 - mean_iou: 0.784 - ETA: 53s - loss: 0.0824 - mean_iou: 0.784 - ETA: 51s - loss: 0.0827 - mean_iou: 0.784 - ETA: 50s - loss: 0.0811 - mean_iou: 0.784 - ETA: 48s - loss: 0.0852 - mean_iou: 0.784 - ETA: 46s - loss: 0.0847 - mean_iou: 0.785 - ETA: 45s - loss: 0.0827 - mean_iou: 0.785 - ETA: 43s - loss: 0.0830 - mean_iou: 0.785 - ETA: 42s - loss: 0.0830 - mean_iou: 0.785 - ETA: 40s - loss: 0.0804 - mean_iou: 0.785 - ETA: 38s - loss: 0.0820 - mean_iou: 0.785 - ETA: 37s - loss: 0.0814 - mean_iou: 0.785 - ETA: 35s - loss: 0.0790 - mean_iou: 0.785 - ETA: 33s - loss: 0.0766 - mean_iou: 0.785 - ETA: 32s - loss: 0.0764 - mean_iou: 0.785 - ETA: 30s - loss: 0.0763 - mean_iou: 0.785 - ETA: 28s - loss: 0.0764 - mean_iou: 0.785 - ETA: 27s - loss: 0.0766 - mean_iou: 0.785 - ETA: 25s - loss: 0.0764 - mean_iou: 0.785 - ETA: 24s - loss: 0.0762 - mean_iou: 0.785 - ETA: 22s - loss: 0.0756 - mean_iou: 0.785 - ETA: 20s - loss: 0.0762 - mean_iou: 0.785 - ETA: 19s - loss: 0.0791 - mean_iou: 0.785 - ETA: 17s - loss: 0.0787 - mean_iou: 0.785 - ETA: 15s - loss: 0.0783 - mean_iou: 0.785 - ETA: 14s - loss: 0.0780 - mean_iou: 0.785 - ETA: 12s - loss: 0.0774 - mean_iou: 0.785 - ETA: 10s - loss: 0.0782 - mean_iou: 0.785 - ETA: 9s - loss: 0.0776 - mean_iou: 0.785 - ETA: 7s - loss: 0.0772 - mean_iou: 0.78 - ETA: 6s - loss: 0.0766 - mean_iou: 0.78 - ETA: 4s - loss: 0.0762 - mean_iou: 0.78 - ETA: 2s - loss: 0.0753 - mean_iou: 0.78 - ETA: 1s - loss: 0.0762 - mean_iou: 0.7861
# Epoch 00023: val_loss improved from 0.07637 to 0.07496, saving model to model-dsbowl2018-1.h5
# 603/603 [==============================] - 64s 107ms/step - loss: 0.0762 - mean_iou: 0.7862 - val_loss: 0.0750 - val_mean_iou: 0.7877
# Epoch 24/50
# 592/603 [============================>.] - ETA: 1:00 - loss: 0.0749 - mean_iou: 0.78 - ETA: 58s - loss: 0.0677 - mean_iou: 0.7880 - ETA: 56s - loss: 0.0692 - mean_iou: 0.788 - ETA: 55s - loss: 0.0779 - mean_iou: 0.788 - ETA: 53s - loss: 0.0763 - mean_iou: 0.788 - ETA: 51s - loss: 0.0728 - mean_iou: 0.788 - ETA: 50s - loss: 0.0734 - mean_iou: 0.788 - ETA: 48s - loss: 0.0734 - mean_iou: 0.788 - ETA: 47s - loss: 0.0752 - mean_iou: 0.788 - ETA: 45s - loss: 0.0750 - mean_iou: 0.788 - ETA: 43s - loss: 0.0754 - mean_iou: 0.788 - ETA: 42s - loss: 0.0747 - mean_iou: 0.788 - ETA: 40s - loss: 0.0747 - mean_iou: 0.788 - ETA: 38s - loss: 0.0757 - mean_iou: 0.788 - ETA: 37s - loss: 0.0756 - mean_iou: 0.788 - ETA: 35s - loss: 0.0751 - mean_iou: 0.788 - ETA: 33s - loss: 0.0752 - mean_iou: 0.788 - ETA: 32s - loss: 0.0748 - mean_iou: 0.788 - ETA: 30s - loss: 0.0770 - mean_iou: 0.788 - ETA: 28s - loss: 0.0767 - mean_iou: 0.788 - ETA: 27s - loss: 0.0762 - mean_iou: 0.788 - ETA: 25s - loss: 0.0754 - mean_iou: 0.788 - ETA: 24s - loss: 0.0747 - mean_iou: 0.788 - ETA: 22s - loss: 0.0754 - mean_iou: 0.788 - ETA: 20s - loss: 0.0771 - mean_iou: 0.788 - ETA: 19s - loss: 0.0765 - mean_iou: 0.788 - ETA: 17s - loss: 0.0758 - mean_iou: 0.789 - ETA: 15s - loss: 0.0746 - mean_iou: 0.789 - ETA: 14s - loss: 0.0744 - mean_iou: 0.789 - ETA: 12s - loss: 0.0748 - mean_iou: 0.789 - ETA: 10s - loss: 0.0751 - mean_iou: 0.789 - ETA: 9s - loss: 0.0753 - mean_iou: 0.789 - ETA: 7s - loss: 0.0747 - mean_iou: 0.78 - ETA: 6s - loss: 0.0740 - mean_iou: 0.78 - ETA: 4s - loss: 0.0731 - mean_iou: 0.78 - ETA: 2s - loss: 0.0735 - mean_iou: 0.78 - ETA: 1s - loss: 0.0745 - mean_iou: 0.7893
# Epoch 00024: val_loss did not improve
# 603/603 [==============================] - 64s 106ms/step - loss: 0.0743 - mean_iou: 0.7894 - val_loss: 0.0785 - val_mean_iou: 0.7908
# Epoch 25/50
# 592/603 [============================>.] - ETA: 59s - loss: 0.0914 - mean_iou: 0.791 - ETA: 58s - loss: 0.0709 - mean_iou: 0.791 - ETA: 56s - loss: 0.0767 - mean_iou: 0.791 - ETA: 55s - loss: 0.0780 - mean_iou: 0.791 - ETA: 53s - loss: 0.0773 - mean_iou: 0.791 - ETA: 52s - loss: 0.0747 - mean_iou: 0.791 - ETA: 50s - loss: 0.0781 - mean_iou: 0.791 - ETA: 48s - loss: 0.0757 - mean_iou: 0.791 - ETA: 47s - loss: 0.0740 - mean_iou: 0.791 - ETA: 45s - loss: 0.0717 - mean_iou: 0.791 - ETA: 43s - loss: 0.0723 - mean_iou: 0.791 - ETA: 42s - loss: 0.0722 - mean_iou: 0.791 - ETA: 40s - loss: 0.0725 - mean_iou: 0.791 - ETA: 38s - loss: 0.0732 - mean_iou: 0.791 - ETA: 37s - loss: 0.0731 - mean_iou: 0.791 - ETA: 35s - loss: 0.0714 - mean_iou: 0.791 - ETA: 33s - loss: 0.0715 - mean_iou: 0.791 - ETA: 32s - loss: 0.0713 - mean_iou: 0.791 - ETA: 30s - loss: 0.0715 - mean_iou: 0.791 - ETA: 28s - loss: 0.0722 - mean_iou: 0.791 - ETA: 27s - loss: 0.0714 - mean_iou: 0.791 - ETA: 25s - loss: 0.0732 - mean_iou: 0.791 - ETA: 24s - loss: 0.0734 - mean_iou: 0.791 - ETA: 22s - loss: 0.0734 - mean_iou: 0.791 - ETA: 20s - loss: 0.0729 - mean_iou: 0.791 - ETA: 19s - loss: 0.0720 - mean_iou: 0.791 - ETA: 17s - loss: 0.0719 - mean_iou: 0.791 - ETA: 15s - loss: 0.0718 - mean_iou: 0.792 - ETA: 14s - loss: 0.0718 - mean_iou: 0.792 - ETA: 12s - loss: 0.0728 - mean_iou: 0.792 - ETA: 10s - loss: 0.0725 - mean_iou: 0.792 - ETA: 9s - loss: 0.0729 - mean_iou: 0.792 - ETA: 7s - loss: 0.0731 - mean_iou: 0.79 - ETA: 6s - loss: 0.0743 - mean_iou: 0.79 - ETA: 4s - loss: 0.0748 - mean_iou: 0.79 - ETA: 2s - loss: 0.0747 - mean_iou: 0.79 - ETA: 1s - loss: 0.0745 - mean_iou: 0.7922
# Epoch 00025: val_loss improved from 0.07496 to 0.07214, saving model to model-dsbowl2018-1.h5
# 603/603 [==============================] - 64s 107ms/step - loss: 0.0740 - mean_iou: 0.7923 - val_loss: 0.0721 - val_mean_iou: 0.7936
# Epoch 26/50
# ...
# Epoch 00027: val_loss did not improve
# 603/603 [==============================] - 64s 107ms/step - loss: 0.0727 - mean_iou: 0.7974 - val_loss: 0.0781 - val_mean_iou: 0.7986
# Epoch 28/50
# 592/603 [============================>.] - ETA: 58s - loss: 0.0611 - mean_iou: 0.798 - ETA: 57s - loss: 0.0672 - mean_iou: 0.798 - ETA: 56s - loss: 0.0692 - mean_iou: 0.798 - ETA: 54s - loss: 0.0720 - mean_iou: 0.798 - ETA: 53s - loss: 0.0714 - mean_iou: 0.798 - ETA: 51s - loss: 0.0785 - mean_iou: 0.798 - ETA: 50s - loss: 0.0764 - mean_iou: 0.798 - ETA: 48s - loss: 0.0757 - mean_iou: 0.798 - ETA: 46s - loss: 0.0725 - mean_iou: 0.798 - ETA: 45s - loss: 0.0726 - mean_iou: 0.799 - ETA: 43s - loss: 0.0728 - mean_iou: 0.799 - ETA: 41s - loss: 0.0726 - mean_iou: 0.799 - ETA: 40s - loss: 0.0726 - mean_iou: 0.799 - ETA: 38s - loss: 0.0725 - mean_iou: 0.799 - ETA: 37s - loss: 0.0712 - mean_iou: 0.799 - ETA: 35s - loss: 0.0708 - mean_iou: 0.799 - ETA: 33s - loss: 0.0711 - mean_iou: 0.799 - ETA: 32s - loss: 0.0710 - mean_iou: 0.799 - ETA: 30s - loss: 0.0708 - mean_iou: 0.799 - ETA: 28s - loss: 0.0706 - mean_iou: 0.799 - ETA: 27s - loss: 0.0706 - mean_iou: 0.799 - ETA: 25s - loss: 0.0702 - mean_iou: 0.799 - ETA: 24s - loss: 0.0708 - mean_iou: 0.799 - ETA: 22s - loss: 0.0702 - mean_iou: 0.799 - ETA: 20s - loss: 0.0697 - mean_iou: 0.799 - ETA: 19s - loss: 0.0695 - mean_iou: 0.799 - ETA: 17s - loss: 0.0699 - mean_iou: 0.799 - ETA: 15s - loss: 0.0719 - mean_iou: 0.799 - ETA: 14s - loss: 0.0722 - mean_iou: 0.799 - ETA: 12s - loss: 0.0723 - mean_iou: 0.799 - ETA: 10s - loss: 0.0734 - mean_iou: 0.799 - ETA: 9s - loss: 0.0742 - mean_iou: 0.799 - ETA: 7s - loss: 0.0734 - mean_iou: 0.79 - ETA: 6s - loss: 0.0729 - mean_iou: 0.79 - ETA: 4s - loss: 0.0730 - mean_iou: 0.79 - ETA: 2s - loss: 0.0723 - mean_iou: 0.79 - ETA: 1s - loss: 0.0718 - mean_iou: 0.7998
# Epoch 00028: val_loss improved from 0.07009 to 0.06892, saving model to model-dsbowl2018-1.h5
# 603/603 [==============================] - 64s 107ms/step - loss: 0.0719 - mean_iou: 0.7998 - val_loss: 0.0689 - val_mean_iou: 0.8009
# Epoch 29/50
# 592/603 [============================>.] - ETA: 1:00 - loss: 0.0855 - mean_iou: 0.80 - ETA: 58s - loss: 0.0762 - mean_iou: 0.8011 - ETA: 56s - loss: 0.0975 - mean_iou: 0.801 - ETA: 55s - loss: 0.0858 - mean_iou: 0.801 - ETA: 53s - loss: 0.0774 - mean_iou: 0.801 - ETA: 52s - loss: 0.0801 - mean_iou: 0.801 - ETA: 50s - loss: 0.0768 - mean_iou: 0.801 - ETA: 48s - loss: 0.0774 - mean_iou: 0.801 - ETA: 46s - loss: 0.0800 - mean_iou: 0.801 - ETA: 45s - loss: 0.0781 - mean_iou: 0.801 - ETA: 43s - loss: 0.0772 - mean_iou: 0.801 - ETA: 42s - loss: 0.0753 - mean_iou: 0.801 - ETA: 40s - loss: 0.0754 - mean_iou: 0.801 - ETA: 38s - loss: 0.0749 - mean_iou: 0.801 - ETA: 37s - loss: 0.0730 - mean_iou: 0.801 - ETA: 35s - loss: 0.0724 - mean_iou: 0.801 - ETA: 33s - loss: 0.0708 - mean_iou: 0.801 - ETA: 32s - loss: 0.0709 - mean_iou: 0.801 - ETA: 30s - loss: 0.0697 - mean_iou: 0.801 - ETA: 28s - loss: 0.0703 - mean_iou: 0.801 - ETA: 27s - loss: 0.0705 - mean_iou: 0.801 - ETA: 25s - loss: 0.0717 - mean_iou: 0.801 - ETA: 24s - loss: 0.0727 - mean_iou: 0.801 - ETA: 22s - loss: 0.0727 - mean_iou: 0.801 - ETA: 20s - loss: 0.0725 - mean_iou: 0.801 - ETA: 19s - loss: 0.0721 - mean_iou: 0.801 - ETA: 17s - loss: 0.0712 - mean_iou: 0.801 - ETA: 15s - loss: 0.0734 - mean_iou: 0.801 - ETA: 14s - loss: 0.0728 - mean_iou: 0.801 - ETA: 12s - loss: 0.0725 - mean_iou: 0.801 - ETA: 10s - loss: 0.0719 - mean_iou: 0.801 - ETA: 9s - loss: 0.0714 - mean_iou: 0.801 - ETA: 7s - loss: 0.0710 - mean_iou: 0.80 - ETA: 6s - loss: 0.0711 - mean_iou: 0.80 - ETA: 4s - loss: 0.0710 - mean_iou: 0.80 - ETA: 2s - loss: 0.0719 - mean_iou: 0.80 - ETA: 1s - loss: 0.0716 - mean_iou: 0.8020
# Epoch 00029: val_loss did not improve
# 603/603 [==============================] - 64s 107ms/step - loss: 0.0713 - mean_iou: 0.8020 - val_loss: 0.0704 - val_mean_iou: 0.8031
# Epoch 30/50
# 592/603 [============================>.] - ETA: 1:00 - loss: 0.0549 - mean_iou: 0.80 - ETA: 58s - loss: 0.0582 - mean_iou: 0.8033 - ETA: 57s - loss: 0.0520 - mean_iou: 0.803 - ETA: 55s - loss: 0.0594 - mean_iou: 0.803 - ETA: 53s - loss: 0.0638 - mean_iou: 0.803 - ETA: 52s - loss: 0.0663 - mean_iou: 0.803 - ETA: 50s - loss: 0.0631 - mean_iou: 0.803 - ETA: 48s - loss: 0.0619 - mean_iou: 0.803 - ETA: 47s - loss: 0.0618 - mean_iou: 0.803 - ETA: 45s - loss: 0.0630 - mean_iou: 0.803 - ETA: 43s - loss: 0.0615 - mean_iou: 0.803 - ETA: 42s - loss: 0.0634 - mean_iou: 0.803 - ETA: 40s - loss: 0.0627 - mean_iou: 0.803 - ETA: 38s - loss: 0.0626 - mean_iou: 0.803 - ETA: 37s - loss: 0.0637 - mean_iou: 0.803 - ETA: 35s - loss: 0.0650 - mean_iou: 0.803 - ETA: 33s - loss: 0.0656 - mean_iou: 0.803 - ETA: 32s - loss: 0.0657 - mean_iou: 0.803 - ETA: 30s - loss: 0.0660 - mean_iou: 0.803 - ETA: 28s - loss: 0.0670 - mean_iou: 0.803 - ETA: 27s - loss: 0.0682 - mean_iou: 0.803 - ETA: 25s - loss: 0.0687 - mean_iou: 0.803 - ETA: 24s - loss: 0.0712 - mean_iou: 0.803 - ETA: 22s - loss: 0.0706 - mean_iou: 0.803 - ETA: 21s - loss: 0.0700 - mean_iou: 0.803 - ETA: 19s - loss: 0.0694 - mean_iou: 0.804 - ETA: 17s - loss: 0.0695 - mean_iou: 0.804 - ETA: 16s - loss: 0.0693 - mean_iou: 0.804 - ETA: 14s - loss: 0.0698 - mean_iou: 0.804 - ETA: 12s - loss: 0.0695 - mean_iou: 0.804 - ETA: 11s - loss: 0.0691 - mean_iou: 0.804 - ETA: 9s - loss: 0.0703 - mean_iou: 0.804 - ETA: 7s - loss: 0.0701 - mean_iou: 0.80 - ETA: 6s - loss: 0.0703 - mean_iou: 0.80 - ETA: 4s - loss: 0.0703 - mean_iou: 0.80 - ETA: 2s - loss: 0.0700 - mean_iou: 0.80 - ETA: 1s - loss: 0.0697 - mean_iou: 0.8042
# Epoch 00030: val_loss improved from 0.06892 to 0.06884, saving model to model-dsbowl2018-1.h5
# 603/603 [==============================] - 66s 110ms/step - loss: 0.0693 - mean_iou: 0.8042 - val_loss: 0.0688 - val_mean_iou: 0.8053
# Epoch 31/50
# 592/603 [============================>.] - ETA: 1:00 - loss: 0.0658 - mean_iou: 0.80 - ETA: 59s - loss: 0.0701 - mean_iou: 0.8054 - ETA: 57s - loss: 0.0710 - mean_iou: 0.805 - ETA: 55s - loss: 0.0691 - mean_iou: 0.805 - ETA: 54s - loss: 0.0658 - mean_iou: 0.805 - ETA: 52s - loss: 0.0643 - mean_iou: 0.805 - ETA: 51s - loss: 0.0639 - mean_iou: 0.805 - ETA: 49s - loss: 0.0632 - mean_iou: 0.805 - ETA: 47s - loss: 0.0612 - mean_iou: 0.805 - ETA: 46s - loss: 0.0609 - mean_iou: 0.805 - ETA: 44s - loss: 0.0621 - mean_iou: 0.805 - ETA: 42s - loss: 0.0637 - mean_iou: 0.805 - ETA: 41s - loss: 0.0634 - mean_iou: 0.805 - ETA: 39s - loss: 0.0684 - mean_iou: 0.805 - ETA: 37s - loss: 0.0697 - mean_iou: 0.805 - ETA: 36s - loss: 0.0682 - mean_iou: 0.805 - ETA: 34s - loss: 0.0682 - mean_iou: 0.805 - ETA: 32s - loss: 0.0680 - mean_iou: 0.805 - ETA: 31s - loss: 0.0686 - mean_iou: 0.805 - ETA: 29s - loss: 0.0682 - mean_iou: 0.805 - ETA: 27s - loss: 0.0671 - mean_iou: 0.805 - ETA: 26s - loss: 0.0686 - mean_iou: 0.805 - ETA: 24s - loss: 0.0679 - mean_iou: 0.805 - ETA: 22s - loss: 0.0668 - mean_iou: 0.805 - ETA: 21s - loss: 0.0665 - mean_iou: 0.806 - ETA: 19s - loss: 0.0687 - mean_iou: 0.806 - ETA: 17s - loss: 0.0680 - mean_iou: 0.806 - ETA: 16s - loss: 0.0683 - mean_iou: 0.806 - ETA: 14s - loss: 0.0679 - mean_iou: 0.806 - ETA: 12s - loss: 0.0674 - mean_iou: 0.806 - ETA: 11s - loss: 0.0695 - mean_iou: 0.806 - ETA: 9s - loss: 0.0693 - mean_iou: 0.806 - ETA: 7s - loss: 0.0694 - mean_iou: 0.80 - ETA: 6s - loss: 0.0697 - mean_iou: 0.80 - ETA: 4s - loss: 0.0706 - mean_iou: 0.80 - ETA: 2s - loss: 0.0708 - mean_iou: 0.80 - ETA: 1s - loss: 0.0707 - mean_iou: 0.8063
# Epoch 00031: val_loss did not improve
# 603/603 [==============================] - 65s 109ms/step - loss: 0.0703 - mean_iou: 0.8063 - val_loss: 0.0705 - val_mean_iou: 0.8073
# Epoch 32/50
# 592/603 [============================>.] - ETA: 1:00 - loss: 0.0865 - mean_iou: 0.80 - ETA: 59s - loss: 0.0846 - mean_iou: 0.8074 - ETA: 57s - loss: 0.0854 - mean_iou: 0.807 - ETA: 56s - loss: 0.0811 - mean_iou: 0.807 - ETA: 54s - loss: 0.0744 - mean_iou: 0.807 - ETA: 52s - loss: 0.0723 - mean_iou: 0.807 - ETA: 51s - loss: 0.0704 - mean_iou: 0.807 - ETA: 49s - loss: 0.0707 - mean_iou: 0.807 - ETA: 47s - loss: 0.0735 - mean_iou: 0.807 - ETA: 46s - loss: 0.0775 - mean_iou: 0.807 - ETA: 44s - loss: 0.0766 - mean_iou: 0.807 - ETA: 42s - loss: 0.0765 - mean_iou: 0.807 - ETA: 41s - loss: 0.0753 - mean_iou: 0.807 - ETA: 39s - loss: 0.0751 - mean_iou: 0.807 - ETA: 37s - loss: 0.0737 - mean_iou: 0.807 - ETA: 36s - loss: 0.0720 - mean_iou: 0.807 - ETA: 34s - loss: 0.0730 - mean_iou: 0.807 - ETA: 32s - loss: 0.0720 - mean_iou: 0.807 - ETA: 31s - loss: 0.0723 - mean_iou: 0.807 - ETA: 29s - loss: 0.0733 - mean_iou: 0.807 - ETA: 27s - loss: 0.0732 - mean_iou: 0.807 - ETA: 26s - loss: 0.0722 - mean_iou: 0.807 - ETA: 24s - loss: 0.0713 - mean_iou: 0.808 - ETA: 22s - loss: 0.0722 - mean_iou: 0.808 - ETA: 21s - loss: 0.0721 - mean_iou: 0.808 - ETA: 19s - loss: 0.0715 - mean_iou: 0.808 - ETA: 17s - loss: 0.0722 - mean_iou: 0.808 - ETA: 16s - loss: 0.0714 - mean_iou: 0.808 - ETA: 14s - loss: 0.0706 - mean_iou: 0.808 - ETA: 12s - loss: 0.0700 - mean_iou: 0.808 - ETA: 11s - loss: 0.0702 - mean_iou: 0.808 - ETA: 9s - loss: 0.0709 - mean_iou: 0.808 - ETA: 7s - loss: 0.0720 - mean_iou: 0.80 - ETA: 6s - loss: 0.0728 - mean_iou: 0.80 - ETA: 4s - loss: 0.0732 - mean_iou: 0.80 - ETA: 2s - loss: 0.0731 - mean_iou: 0.80 - ETA: 1s - loss: 0.0723 - mean_iou: 0.8083
# Epoch 00032: val_loss did not improve
# 603/603 [==============================] - 66s 110ms/step - loss: 0.0726 - mean_iou: 0.8083 - val_loss: 0.0730 - val_mean_iou: 0.8091
# Epoch 33/50
# 592/603 [============================>.] - ETA: 1:01 - loss: 0.0740 - mean_iou: 0.80 - ETA: 59s - loss: 0.0745 - mean_iou: 0.8092 - ETA: 57s - loss: 0.0771 - mean_iou: 0.809 - ETA: 56s - loss: 0.0817 - mean_iou: 0.809 - ETA: 54s - loss: 0.0824 - mean_iou: 0.809 - ETA: 52s - loss: 0.0800 - mean_iou: 0.809 - ETA: 51s - loss: 0.0844 - mean_iou: 0.809 - ETA: 49s - loss: 0.0830 - mean_iou: 0.809 - ETA: 47s - loss: 0.0824 - mean_iou: 0.809 - ETA: 46s - loss: 0.0835 - mean_iou: 0.809 - ETA: 44s - loss: 0.0820 - mean_iou: 0.809 - ETA: 42s - loss: 0.0797 - mean_iou: 0.809 - ETA: 41s - loss: 0.0801 - mean_iou: 0.809 - ETA: 39s - loss: 0.0798 - mean_iou: 0.809 - ETA: 37s - loss: 0.0782 - mean_iou: 0.809 - ETA: 36s - loss: 0.0775 - mean_iou: 0.809 - ETA: 34s - loss: 0.0766 - mean_iou: 0.809 - ETA: 32s - loss: 0.0774 - mean_iou: 0.809 - ETA: 31s - loss: 0.0770 - mean_iou: 0.809 - ETA: 29s - loss: 0.0760 - mean_iou: 0.809 - ETA: 27s - loss: 0.0767 - mean_iou: 0.809 - ETA: 26s - loss: 0.0750 - mean_iou: 0.809 - ETA: 24s - loss: 0.0750 - mean_iou: 0.809 - ETA: 22s - loss: 0.0751 - mean_iou: 0.809 - ETA: 21s - loss: 0.0774 - mean_iou: 0.809 - ETA: 19s - loss: 0.0779 - mean_iou: 0.809 - ETA: 17s - loss: 0.0772 - mean_iou: 0.809 - ETA: 16s - loss: 0.0776 - mean_iou: 0.809 - ETA: 14s - loss: 0.0770 - mean_iou: 0.809 - ETA: 12s - loss: 0.0764 - mean_iou: 0.809 - ETA: 11s - loss: 0.0760 - mean_iou: 0.809 - ETA: 9s - loss: 0.0764 - mean_iou: 0.809 - ETA: 7s - loss: 0.0755 - mean_iou: 0.80 - ETA: 6s - loss: 0.0766 - mean_iou: 0.80 - ETA: 4s - loss: 0.0760 - mean_iou: 0.80 - ETA: 2s - loss: 0.0756 - mean_iou: 0.80 - ETA: 1s - loss: 0.0755 - mean_iou: 0.8099
# Epoch 00033: val_loss did not improve
# 603/603 [==============================] - 65s 108ms/step - loss: 0.0756 - mean_iou: 0.8099 - val_loss: 0.0722 - val_mean_iou: 0.8106
# Epoch 34/50
# 592/603 [============================>.] - ETA: 1:01 - loss: 0.0498 - mean_iou: 0.81 - ETA: 59s - loss: 0.0550 - mean_iou: 0.8108 - ETA: 58s - loss: 0.0493 - mean_iou: 0.810 - ETA: 56s - loss: 0.0505 - mean_iou: 0.810 - ETA: 54s - loss: 0.0628 - mean_iou: 0.810 - ETA: 52s - loss: 0.0627 - mean_iou: 0.810 - ETA: 51s - loss: 0.0647 - mean_iou: 0.810 - ETA: 49s - loss: 0.0625 - mean_iou: 0.810 - ETA: 47s - loss: 0.0620 - mean_iou: 0.810 - ETA: 46s - loss: 0.0618 - mean_iou: 0.811 - ETA: 44s - loss: 0.0660 - mean_iou: 0.811 - ETA: 42s - loss: 0.0664 - mean_iou: 0.811 - ETA: 41s - loss: 0.0672 - mean_iou: 0.811 - ETA: 39s - loss: 0.0688 - mean_iou: 0.811 - ETA: 37s - loss: 0.0690 - mean_iou: 0.811 - ETA: 36s - loss: 0.0676 - mean_iou: 0.811 - ETA: 34s - loss: 0.0680 - mean_iou: 0.811 - ETA: 32s - loss: 0.0686 - mean_iou: 0.811 - ETA: 31s - loss: 0.0680 - mean_iou: 0.811 - ETA: 29s - loss: 0.0676 - mean_iou: 0.811 - ETA: 27s - loss: 0.0683 - mean_iou: 0.811 - ETA: 26s - loss: 0.0679 - mean_iou: 0.811 - ETA: 24s - loss: 0.0690 - mean_iou: 0.811 - ETA: 22s - loss: 0.0695 - mean_iou: 0.811 - ETA: 21s - loss: 0.0694 - mean_iou: 0.811 - ETA: 19s - loss: 0.0693 - mean_iou: 0.811 - ETA: 17s - loss: 0.0680 - mean_iou: 0.811 - ETA: 16s - loss: 0.0676 - mean_iou: 0.811 - ETA: 14s - loss: 0.0675 - mean_iou: 0.811 - ETA: 12s - loss: 0.0682 - mean_iou: 0.811 - ETA: 11s - loss: 0.0694 - mean_iou: 0.811 - ETA: 9s - loss: 0.0694 - mean_iou: 0.811 - ETA: 7s - loss: 0.0688 - mean_iou: 0.81 - ETA: 6s - loss: 0.0689 - mean_iou: 0.81 - ETA: 4s - loss: 0.0685 - mean_iou: 0.81 - ETA: 2s - loss: 0.0692 - mean_iou: 0.81 - ETA: 1s - loss: 0.0696 - mean_iou: 0.8115
# Epoch 00034: val_loss did not improve
# 603/603 [==============================] - 66s 110ms/step - loss: 0.0700 - mean_iou: 0.8115 - val_loss: 0.0714 - val_mean_iou: 0.8123
# Epoch 35/50
# 592/603 [============================>.] - ETA: 1:00 - loss: 0.0681 - mean_iou: 0.81 - ETA: 58s - loss: 0.0691 - mean_iou: 0.8124 - ETA: 57s - loss: 0.0706 - mean_iou: 0.812 - ETA: 56s - loss: 0.0684 - mean_iou: 0.812 - ETA: 54s - loss: 0.0681 - mean_iou: 0.812 - ETA: 53s - loss: 0.0649 - mean_iou: 0.812 - ETA: 52s - loss: 0.0631 - mean_iou: 0.812 - ETA: 50s - loss: 0.0659 - mean_iou: 0.812 - ETA: 49s - loss: 0.0651 - mean_iou: 0.812 - ETA: 47s - loss: 0.0672 - mean_iou: 0.812 - ETA: 45s - loss: 0.0673 - mean_iou: 0.812 - ETA: 43s - loss: 0.0684 - mean_iou: 0.812 - ETA: 42s - loss: 0.0693 - mean_iou: 0.812 - ETA: 40s - loss: 0.0686 - mean_iou: 0.812 - ETA: 38s - loss: 0.0674 - mean_iou: 0.812 - ETA: 37s - loss: 0.0690 - mean_iou: 0.812 - ETA: 35s - loss: 0.0692 - mean_iou: 0.812 - ETA: 33s - loss: 0.0706 - mean_iou: 0.812 - ETA: 32s - loss: 0.0705 - mean_iou: 0.812 - ETA: 30s - loss: 0.0697 - mean_iou: 0.812 - ETA: 28s - loss: 0.0684 - mean_iou: 0.812 - ETA: 27s - loss: 0.0682 - mean_iou: 0.812 - ETA: 25s - loss: 0.0674 - mean_iou: 0.812 - ETA: 23s - loss: 0.0679 - mean_iou: 0.812 - ETA: 21s - loss: 0.0695 - mean_iou: 0.812 - ETA: 20s - loss: 0.0691 - mean_iou: 0.812 - ETA: 18s - loss: 0.0697 - mean_iou: 0.812 - ETA: 16s - loss: 0.0696 - mean_iou: 0.812 - ETA: 15s - loss: 0.0698 - mean_iou: 0.812 - ETA: 13s - loss: 0.0694 - mean_iou: 0.813 - ETA: 11s - loss: 0.0694 - mean_iou: 0.813 - ETA: 9s - loss: 0.0685 - mean_iou: 0.813 - ETA: 8s - loss: 0.0686 - mean_iou: 0.81 - ETA: 6s - loss: 0.0686 - mean_iou: 0.81 - ETA: 4s - loss: 0.0683 - mean_iou: 0.81 - ETA: 2s - loss: 0.0679 - mean_iou: 0.81 - ETA: 1s - loss: 0.0680 - mean_iou: 0.8131
# Epoch 00035: val_loss did not improve
# 603/603 [==============================] - 69s 114ms/step - loss: 0.0692 - mean_iou: 0.8131 - val_loss: 0.0713 - val_mean_iou: 0.8139
# Epoch 00035: early stopping

# %% [markdown]
# All right, looks good! Loss seems to be a bit erratic, though. I'll leave it to you to improve the model architecture and parameters!
#
# # Make predictions
#
# Let's make predictions both on the test set, the val set and the train set (as a sanity check). Remember to load the best saved model if you've used early stopping and checkpointing.

# %%
# Predict on train, val and test
model = load_model('model-dsbowl2018-1.h5', custom_objects={'mean_iou': mean_iou})
preds_train = model.predict(X_train[:int(X_train.shape[0]*0.9)], verbose=1)
preds_val = model.predict(X_train[int(X_train.shape[0]*0.9):], verbose=1)
preds_test = model.predict(X_test, verbose=1)

# Threshold predictions
preds_train_t = (preds_train > 0.5).astype(np.uint8)
preds_val_t = (preds_val > 0.5).astype(np.uint8)
preds_test_t = (preds_test > 0.5).astype(np.uint8)

# Create list of upsampled test masks
preds_test_upsampled = []
for i in range(len(preds_test)):
    preds_test_upsampled.append(resize(np.squeeze(preds_test[i]), 
                                       (sizes_test[i][0], sizes_test[i][1]), 
                                       mode='constant', preserve_range=True))
# Out:
# 603/603 [==============================] - ETA: 22 - ETA: 20 - ETA: 18 - ETA: 17 - ETA: 15 - ETA: 14 - ETA: 13 - ETA: 12 - ETA: 10 - ETA: 9 - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - 21s 34ms/step
# 67/67 [==============================] - ETA:  - ETA:  - 2s 34ms/step
# 65/65 [==============================] - ETA:  - ETA:  - 2s 34ms/step

# %%
# Perform a sanity check on some random training samples
ix = random.randint(0, len(preds_train_t))
imshow(X_train[ix])
plt.show()
imshow(np.squeeze(Y_train[ix]))
plt.show()
imshow(np.squeeze(preds_train_t[ix]))
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and

# %% [markdown]
# The model is at least able to fit to the training data! Certainly a lot of room for improvement even here, but a decent start. How about the validation data?

# %%
# Perform a sanity check on some random validation samples
ix = random.randint(0, len(preds_val_t))
imshow(X_train[int(X_train.shape[0]*0.9):][ix])
plt.show()
imshow(np.squeeze(Y_train[int(Y_train.shape[0]*0.9):][ix]))
plt.show()
imshow(np.squeeze(preds_val_t[ix]))
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and

# %% [markdown]
# Not too shabby! Definitely needs some more training and tweaking.
#
# # Encode and submit our results
#
# Now it's time to submit our results. I've stolen [this](https://www.kaggle.com/rakhlin/fast-run-length-encoding-python) excellent implementation of run-length encoding.

# %%
# Run-length encoding stolen from https://www.kaggle.com/rakhlin/fast-run-length-encoding-python
def rle_encoding(x):
    dots = np.where(x.T.flatten() == 1)[0]
    run_lengths = []
    prev = -2
    for b in dots:
        if (b>prev+1): run_lengths.extend((b + 1, 0))
        run_lengths[-1] += 1
        prev = b
    return run_lengths

def prob_to_rles(x, cutoff=0.5):
    lab_img = label(x > cutoff)
    for i in range(1, lab_img.max() + 1):
        yield rle_encoding(lab_img == i)

# %% [markdown]
# Let's iterate over the test IDs and generate run-length encodings for each seperate mask identified by skimage ...

# %%
new_test_ids = []
rles = []
for n, id_ in enumerate(test_ids):
    rle = list(prob_to_rles(preds_test_upsampled[n]))
    rles.extend(rle)
    new_test_ids.extend([id_] * len(rle))

# %% [markdown]
# ... and then finally create our submission!

# %%
# Create submission DataFrame
sub = pd.DataFrame()
sub['ImageId'] = new_test_ids
sub['EncodedPixels'] = pd.Series(rles).apply(lambda x: ' '.join(str(y) for y in x))
sub.to_csv('sub-dsbowl2018-1.csv', index=False)

# %% [markdown]
# This scored 0.233 on the LB for me. That was with version 2 of this notebook; be aware that the results from the neural network are extremely erratic and vary greatly from run to run (version 3 is significantly worse, for example). Version 7 scores 0.277!
#
# You should easily be able to stabilize and improve the results just by changing a few parameters, tweaking the architecture a little bit and training longer with early stopping.
#
# **Have fun!**
#
# LB score history:
# - Version 7: 0.277 LB
